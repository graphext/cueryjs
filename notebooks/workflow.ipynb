// %%
import { load } from "@std/dotenv";

import { z } from '@zod/zod';


import { generateBrandInfo, generateCompetitorsInfo, concatBrands } from "../src/brands.ts";
import { generatePersonas } from "../src/personas.ts";
import { generateFunnel, iterateFunnelCategories } from "../src/funnel.ts";
import { ModelId } from "../src/models.ts";
import { searchBatch, searchWithFormat } from "../src/search.ts";
import { extractABSForBrandBatch } from "../src/sentiment.ts";
import { Brand } from "../src/schemas/brand.schema.ts";
import { translateBatch } from "../src/translate.ts";
import { audit, enrichAudit } from "../src/audit.ts";

// %%
void await load({
  envPath: "../../.env",
  export: true,
});

// %% [markdown]
// # Setup

// %%
const config = {
  brand: "Peugeot.es",
  sector: "coches eléctricos",
  country: "es",
  language: "es",
  models: ["openai/gpt-4.1-mini"],  //, "google/ai-overview"],
  numPersonas: 5,
  personaModel: "gpt-4.1",
  funnelModel: "gpt-4.1",
};

let start: number;
let duration: string;

// %% [markdown]
// # Brands
//
// Market & sector from brand domain

// %%
start = Date.now();

const brand = await generateBrandInfo({
  brand: config.brand,
  language: config.language,
  model: 'gpt-4.1',
  useSearch: true,
  contextSize: 'high',
});

duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`Generated competitors in ${duration}s`);
console.log(JSON.stringify(brand, null, 2));
// Out:
// Generated competitors in 12.0s
// {
//   "name": "Peugeot España S.A.",
//   "shortName": "Peugeot",
//   "description": "Fabricante y comercializador de automóviles, incluyendo turismos, vehículos comerciales y deportivos.",
//   "domain": "https://www.peugeot.es",
//   "sectors": [
//     "Automoción",
//     "Vehículos comerciales",
//     "Vehículos deportivos"
//   ],
//   "markets": [
//     "España",
//     "Europa",
//     "América Latina",
//     "Asia"
//   ],
//   "portfolio": [
//     {
//       "name": "Peugeot 208",
//       "category": "Turismo compacto"
//     },
//     {
//       "name": "Peugeot 3008",
//       "category": "SUV"
//     },
//     {
//       "name": "Peugeot Partner",
//       "category": "Vehículo comercial"
//     },
//     {
//       "name": "Peugeot e-208",
//       "category": "Vehículo eléctrico"
//     }
//   ],
//   "marketPosition": "leader",
//   "favicon": "https://www.peugeot.es/favicon.ico"
// }

// %%
start = Date.now();

const competitors = await generateCompetitorsInfo({
  brand: config.brand,
  sector: config.sector,
  market: config.country,
  strict: true,
  language: config.language,
  model: 'gpt-4.1',
  useSearch: true,
  contextSize: 'high',
});

duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`Generated competitors in ${duration}s`);
console.log(competitors[0]);
// Out:
// Generated competitors in 50.9s
// {
//   name: "Renault",
//   shortName: "Renault",
//   description: "Fabricante francés de automóviles con una amplia gama de vehículos eléctricos.",
//   domain: "https://www.renault.es",
//   sectors: [ "Automoción" ],
//   markets: [ "Europa", "España" ],
//   portfolio: [
//     { name: "Renault ZOE", category: "Coche eléctrico" },
//     { name: "Renault Twingo E-Tech", category: "Coche eléctrico" },
//     { name: "Renault Mégane E-Tech", category: "Coche eléctrico" }
//   ],
//   marketPosition: "leader",
//   favicon: "https://www.renault.es/favicon.ico"
// }

// %%
const all_brands : Brand[] = concatBrands([brand], competitors);
all_brands
// Out:
// [
//   {
//     name: "Peugeot España S.A.",
//     shortName: "Peugeot",
//     description: "Fabricante y comercializador de automóviles, incluyendo turismos, vehículos comerciales y deportivos.",
//     domain: "https://www.peugeot.es",
//     sectors: [ "Automoción", "Vehículos comerciales", "Vehículos deportivos" ],
//     markets: [ "España", "Europa", "América Latina", "Asia" ],
//     portfolio: [
//       { name: "Peugeot 208", category: "Turismo compacto" },
//       { name: "Peugeot 3008", category: "SUV" },
//       { name: "Peugeot Partner", category: "Vehículo comercial" },
//       { name: "Peugeot e-208", category: "Vehículo eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.peugeot.es/favicon.ico",
//     isCompetitor: false
//   },
//   {
//     name: "Renault",
//     shortName: "Renault",
//     description: "Fabricante francés de automóviles con una amplia gama de vehículos eléctricos.",
//     domain: "https://www.renault.es",
//     sectors: [ "Automoción" ],
//     markets: [ "Europa", "España" ],
//     portfolio: [
//       { name: "Renault ZOE", category: "Coche eléctrico" },
//       { name: "Renault Twingo E-Tech", category: "Coche eléctrico" },
//       { name: "Renault Mégane E-Tech", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.renault.es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "Tesla, Inc.",
//     shortName: "Tesla",
//     description: "Empresa estadounidense especializada en vehículos eléctricos de alta gama.",
//     domain: "https://www.tesla.com/es_es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "Tesla Model 3", category: "Coche eléctrico" },
//       { name: "Tesla Model Y", category: "Coche eléctrico" },
//       { name: "Tesla Model S", category: "Coche eléctrico" },
//       { name: "Tesla Model X", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.tesla.com/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "Nissan Motor Co., Ltd.",
//     shortName: "Nissan",
//     description: "Fabricante japonés de automóviles con presencia en el mercado de vehículos eléctricos.",
//     domain: "https://www.nissan.es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "Nissan LEAF", category: "Coche eléctrico" },
//       { name: "Nissan Ariya", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.nissan.es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "Volkswagen AG",
//     shortName: "Volkswagen",
//     description: "Fabricante alemán de automóviles con una creciente gama de vehículos eléctricos.",
//     domain: "https://www.volkswagen.es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "Volkswagen ID.3", category: "Coche eléctrico" },
//       { name: "Volkswagen ID.4", category: "Coche eléctrico" },
//       { name: "Volkswagen ID.5", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.volkswagen.es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "BMW AG",
//     shortName: "BMW",
//     description: "Fabricante alemán de automóviles premium con una línea de vehículos eléctricos.",
//     domain: "https://www.bmw.es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "BMW i3", category: "Coche eléctrico" },
//       { name: "BMW i4", category: "Coche eléctrico" },
//       { name: "BMW iX3", category: "Coche eléctrico" },
//       { name: "BMW iX", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.bmw.es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "Hyundai Motor Company",
//     shortName: "Hyundai",
//     description: "Fabricante surcoreano de automóviles con una gama de vehículos eléctricos.",
//     domain: "https://www.hyundai.es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "Hyundai Kona Eléctrico", category: "Coche eléctrico" },
//       { name: "Hyundai IONIQ 5", category: "Coche eléctrico" },
//       { name: "Hyundai IONIQ 6", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.hyundai.es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "Kia Corporation",
//     shortName: "Kia",
//     description: "Fabricante surcoreano de automóviles con una oferta creciente de vehículos eléctricos.",
//     domain: "https://www.kia.com/es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "Kia e-Niro", category: "Coche eléctrico" },
//       { name: "Kia EV6", category: "Coche eléctrico" },
//       { name: "Kia Soul EV", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.kia.com/es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "Mercedes-Benz Group AG",
//     shortName: "Mercedes-Benz",
//     description: "Fabricante alemán de automóviles de lujo con una línea de vehículos eléctricos.",
//     domain: "https://www.mercedes-benz.es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "Mercedes-Benz EQA", category: "Coche eléctrico" },
//       { name: "Mercedes-Benz EQB", category: "Coche eléctrico" },
//       { name: "Mercedes-Benz EQC", category: "Coche eléctrico" },
//       { name: "Mercedes-Benz EQS", category: "Coche eléctrico" }
//     ],
//     marketPosition: "leader",
//     favicon: "https://www.mercedes-benz.es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "BYD Company Limited",
//     shortName: "BYD",
//     description: "Fabricante chino de automóviles y baterías con una creciente presencia en el mercado de vehículos eléctricos.",
//     domain: "https://www.byd.com/es",
//     sectors: [ "Automoción" ],
//     markets: [ "Global", "España" ],
//     portfolio: [
//       { name: "BYD Atto 3", category: "Coche eléctrico" },
//       { name: "BYD Dolphin", category: "Coche eléctrico" },
//       { name: "BYD Tang", category: "Coche eléctrico" }
//     ],
//     marketPosition: "challenger",
//     favicon: "https://www.byd.com/es/favicon.ico",
//     isCompetitor: true
//   },
//   {
//     name: "MG Motor",
//     shortName: "MG",
//     description: "Fabricante británico de automóviles con una oferta de vehículos eléctricos asequibles.",
//     domain: "https://www.mgmotor.es",
//     sectors: [ "Automoción" ],
//     markets: [ "Europa", "España" ],
//     portfolio: [
//       { name: "MG4 Electric", category: "Coche eléctrico" },
//       { name: "MG ZS EV", category: "Coche eléctrico" },
//       { name: "MG5 EV", category: "Coche eléctrico" }
//     ],
//     marketPosition: "challenger",
//     favicon: "https://www.mgmotor.es/favicon.ico",
//     isCompetitor: true
//   }
// ]

// %% [markdown]
//  # Personas

// %%
start = Date.now();
const personas = await generatePersonas({
  sector: config.sector,
  market: config.country,
  brand: config.brand,
  language: "spanish",
  count: config.numPersonas,
}
);
duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`Generated personas in ${duration}s`);
console.log(personas);
// Out:
// Generated personas in 17.2s
// [
//   {
//     name: "Padre Ahorrador Urbano",
//     description: "Padre de familia de entre 35 y 50 años que reside en grandes ciudades y busca eficiencia, seguridad y ahorro a la hora de cambiar de coche familiar. Le interesa la movilidad sostenible y desea reducir los costes asociados al uso del coche tradicional, especialmente en desplazamientos diarios. Evalúa mucho la relación calidad-precio y valora la facilidad de carga, autonomía y facilidades para familias.",
//     keywordSeeds: [
//       "mejor coche eléctrico familiar",
//       "coches eléctricos para familias",
//       "autonomía coche eléctrico",
//       "ahorro coche eléctrico",
//       "coche eléctrico carga rápida",
//       "comparativa coches eléctricos",
//       "seguridad coche eléctrico",
//       "maletero grande coche eléctrico"
//     ]
//   },
//   {
//     name: "Joven Profesional Eco-Consciente",
//     description: "Profesional joven, entre 25 y 35 años, con alto nivel educativo y conciencia medioambiental. Vive en ciudad, utiliza tecnología en su día a día y busca opciones de movilidad respetuosas con el medio ambiente. Está dispuesto a invertir en un coche eléctrico que sea moderno y eficiente, y le interesa la innovación y las ayudas para coches sostenibles.",
//     keywordSeeds: [
//       "coches eléctricos sostenibles",
//       "mejor coche eléctrico pequeño",
//       "ayudas coche eléctrico España",
//       "ventajas coches eléctricos",
//       "coche eléctrico autonomía ciudad",
//       "movilidad sostenible coche eléctrico",
//       "recarga coche eléctrico ciudad",
//       "tecnología coche eléctrico"
//     ]
//   },
//   {
//     name: "Empresario Práctico de Pymes",
//     description: "Propietario o gerente de pequeña o mediana empresa que busca renovar la flota de vehículos corporativos. Necesita vehículos eléctricos fiables, con bajo coste de mantenimiento y buena imagen para trasladar valores de sostenibilidad a sus clientes.",
//     keywordSeeds: [
//       "coches eléctricos para empresas",
//       "vehículos eléctricos flota empresarial",
//       "renting coche eléctrico pymes",
//       "coches eléctricos consumo bajo",
//       "coste mantenimiento coche eléctrico",
//       "descuento coches eléctricos empresas",
//       "coche comercial eléctrico",
//       "IVA coche eléctrico empresa"
//     ]
//   },
//   {
//     name: "Amante de la Tecnología y la Innovación",
//     description: "Hombre o mujer de 30 a 45 años, muy interesado en las últimas novedades tecnológicas y gadgets. Busca un coche eléctrico con conectividad avanzada, asistentes de conducción y diseño moderno. Suele ser early adopter y le gusta presumir de lo último en tecnología ante amigos y familiares.",
//     keywordSeeds: [
//       "mejor coche eléctrico tecnología",
//       "coches eléctricos conectividad avanzada",
//       "asistente conducción coche eléctrico",
//       "coches eléctricos diseño moderno",
//       "gadgets coche eléctrico",
//       "novedades coches eléctricos",
//       "coche eléctrico inteligente",
//       "tecnología punta coches eléctricos"
//     ]
//   },
//   {
//     name: "Senior Activo Movilidad Sostenible",
//     description: "Persona mayor de 55 años que lleva un estilo de vida activo y busca alternativas de movilidad que reduzcan su huella ecológica. Desea un coche eléctrico fiable para sus desplazamientos cotidianos, viajes cortos y visitas a familia y amigos. Valora la facilidad de uso, la comodidad y el servicio postventa.",
//     keywordSeeds: [
//       "coche eléctrico fácil de usar",
//       "autonomía coches eléctricos para mayores",
//       "coche eléctrico cómodo",
//       "mejores coches eléctricos 2024",
//       "fiabilidad coche eléctrico",
//       "servicio postventa coche eléctrico",
//       "coche eléctrico sin complicaciones",
//       "descuentos coches eléctricos jubilados"
//     ]
//   }
// ]

// %% [markdown]
// # Funnel

// %%
start = Date.now();
const funnel = await generateFunnel({
  sector: config.sector,
  language: config.language,
  country: config.country,
});
duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`✅ Funnel customized and seeded in ${duration}s!\n`);
for (const [stage, goal, category] of iterateFunnelCategories(funnel)) {
    console.log(`Stage: ${stage}, Goal: ${goal}, Category: ${category.name}, numSeeds: ${category.examples.length}`);
}
// Out:
// ✅ Funnel customized and seeded in 39.0s!
//
// Stage: Conciencia / Descubrimiento, Goal: Reconocimiento del problema, educación., Category: Identificación del Problema, numSeeds: 10
// Stage: Conciencia / Descubrimiento, Goal: Reconocimiento del problema, educación., Category: Educación sobre la Categoría, numSeeds: 10
// Stage: Conciencia / Descubrimiento, Goal: Reconocimiento del problema, educación., Category: Tendencias & Inspiración, numSeeds: 10
// Stage: Consideración / Investigación, Goal: Comparar opciones, evaluar soluciones., Category: Características & Especificaciones, numSeeds: 10
// Stage: Consideración / Investigación, Goal: Comparar opciones, evaluar soluciones., Category: Comparativas, numSeeds: 10
// Stage: Consideración / Investigación, Goal: Comparar opciones, evaluar soluciones., Category: Idoneidad y Casos de Uso, numSeeds: 10
// Stage: Consideración / Investigación, Goal: Comparar opciones, evaluar soluciones., Category: Opiniones & Reseñas, numSeeds: 10
// Stage: Decisión / Evaluación, Goal: El usuario está cerca de actuar, pero aún compara opciones., Category: Precios & Ofertas, numSeeds: 10
// Stage: Decisión / Evaluación, Goal: El usuario está cerca de actuar, pero aún compara opciones., Category: Disponibilidad & Localización, numSeeds: 10
// Stage: Decisión / Evaluación, Goal: El usuario está cerca de actuar, pero aún compara opciones., Category: Intención de Compra, numSeeds: 9
// Stage: Conversión / Acción, Goal: El usuario toma la decisión de compra, registro, demo o prueba., Category: Compra / Solicitud, numSeeds: 10
// Stage: Conversión / Acción, Goal: El usuario toma la decisión de compra, registro, demo o prueba., Category: Promociones & Descuentos Inmediatos, numSeeds: 10
// Stage: Postventa / Retención y Defensa, Goal: Apoyo a clientes, fidelización o recomendación., Category: Uso & Guías Prácticas, numSeeds: 10
// Stage: Postventa / Retención y Defensa, Goal: Apoyo a clientes, fidelización o recomendación., Category: Soporte & Problemas, numSeeds: 10
// Stage: Postventa / Retención y Defensa, Goal: Apoyo a clientes, fidelización o recomendación., Category: Accesorios y Mejoras, numSeeds: 10
// Stage: Postventa / Retención y Defensa, Goal: Apoyo a clientes, fidelización o recomendación., Category: Comunidad & Recomendaciones, numSeeds: 10

// %% [markdown]
// # Keywords

// %%
import { KeywordRecord } from "../lib/GoogleAds/keywordPlanner.ts";
import { expandKeywords } from "../src/keywords.ts";

start = Date.now();

const sectorSeeds = [config.sector];
const personaSeeds = personas.map(p => p.keywordSeeds);
const funnelSeeds = iterateFunnelCategories(funnel)
    .map(([_stage, _goal, category]) => category.examples)
    .toArray();

const allSeeds = [
	...personaSeeds,
	...funnelSeeds,
	sectorSeeds
];

const { filePath, description } = await expandKeywords({
	seedKeywords: allSeeds,
	url: config.brand,
	language: config.language,
	countryISOCode: config.country
});

// %%
import { readParquetRows } from "./readParquetRows.ts";

const keywords = await readParquetRows<KeywordRecord>(filePath);

duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`\n✅ Total: Expanded to ${keywords.length} unique keywords in ${duration}s\n`);
// Out:
// ✅ Total: Expanded to 3753 unique keywords in 189.2s

// %%
keywords[0]
// Out:
// {
//   ROWID: 1,
//   keyword: "mejor coche eléctrico pequeño",
//   avgMonthlySearches: 170,
//   competition: "HIGH",
//   competitionIndex: 95,
//   averageCpc: 0.6685150265693665,
//   lowTopOfPageBid: 0.2526960074901581,
//   highTopOfPageBid: 0.9091740250587463,
//   searchVolume: [
//     110, 140, 140, 170,
//     140, 170, 110, 110,
//     170, 170, 210, 260
//   ],
//   searchVolumeDate: [
//     2024-10-01T00:00:00.000Z,
//     2024-11-01T00:00:00.000Z,
//     2024-12-01T00:00:00.000Z,
//     2025-01-01T00:00:00.000Z,
//     2025-02-01T00:00:00.000Z,
//     2025-03-01T00:00:00.000Z,
//     2025-04-01T00:00:00.000Z,
//     2025-05-01T00:00:00.000Z,
//     2025-06-01T00:00:00.000Z,
//     2025-07-01T00:00:00.000Z,
//     2025-08-01T00:00:00.000Z,
//     2025-09-01T00:00:00.000Z
//   ],
//   searchVolumeGrowthYoy: 136.36363220214844,
//   searchVolumeGrowth3m: 52.94117736816406,
//   searchVolumeGrowth1m: 23.809524536132812,
//   searchVolumeTrend: 0.05167464166879654,
//   concepts: null,
//   conceptGroups: null
// }

// %% [markdown]
// # Translate to Prompts

// %%
let kwds = keywords.map(k => k.keyword);
let prompts = await translateBatch(kwds, config.language, 'gpt-4.1-mini');

// %%
prompts[0]
// Out:
// "¿Cuál es el mejor coche eléctrico pequeño?"

// %% [markdown]
// # Cache generated audit inputs

// %%
const cache = {
    brand,
    competitors,
    funnel,
    personas,
    keywords,
    prompts
};

await Deno.writeTextFile("./cache.json", JSON.stringify(cache, null, 2));
console.log("✅ Cache saved to ./cache.json");
// Out:
// ✅ Cache saved to ./cache.json

// %%
const cached = JSON.parse(await Deno.readTextFile("./cache.json"));
console.log("✅ Cache loaded from ./cache.json");
// Out:
// ✅ Cache loaded from ./cache.json

// %% [markdown]
// # Prepare sample for audit

// %%
// Enrich keywords with translated prompts
const kwdPrompts = cached.keywords.map((keyword, index) => ({
	...keyword,
	prompt: cached.prompts[index]
}));

console.log(`✅ Enriched ${kwdPrompts.length} keywords with prompts`);
console.log("Example:", kwdPrompts[0]);
// Out:
// ✅ Enriched 3753 keywords with prompts
// Example: {
//   ROWID: 1,
//   keyword: "mejor coche eléctrico pequeño",
//   avgMonthlySearches: 170,
//   competition: "HIGH",
//   competitionIndex: 95,
//   averageCpc: 0.6685150265693665,
//   lowTopOfPageBid: 0.2526960074901581,
//   highTopOfPageBid: 0.9091740250587463,
//   searchVolume: [
//     110, 140, 140, 170,
//     140, 170, 110, 110,
//     170, 170, 210, 260
//   ],
//   searchVolumeDate: [
//     "2024-10-01T00:00:00.000Z",
//     "2024-11-01T00:00:00.000Z",
//     "2024-12-01T00:00:00.000Z",
//     "2025-01-01T00:00:00.000Z",
//     "2025-02-01T00:00:00.000Z",
//     "2025-03-01T00:00:00.000Z",
//     "2025-04-01T00:00:00.000Z",
//     "2025-05-01T00:00:00.000Z",
//     "2025-06-01T00:00:00.000Z",
//     "2025-07-01T00:00:00.000Z",
//     "2025-08-01T00:00:00.000Z",
//     "2025-09-01T00:00:00.000Z"
//   ],
//   searchVolumeGrowthYoy: 136.36363220214844,
//   searchVolumeGrowth3m: 52.94117736816406,
//   searchVolumeGrowth1m: 23.809524536132812,
//   searchVolumeTrend: 0.05167464166879654,
//   concepts: null,
//   conceptGroups: null,
//   prompt: "¿Cuál es el mejor coche eléctrico pequeño?"
// }

// %%
function randomSample<T>(array: Array<T>, n: number): Array<T> {
	if (n >= array.length) {
		return [...array];
	}

	const shuffled = [...array];
	for (let i = shuffled.length - 1; i > 0; i--) {
		const j = Math.floor(Math.random() * (i + 1));
		[shuffled[i], shuffled[j]] = [shuffled[j], shuffled[i]];
	}

	return shuffled.slice(0, n);
}

// Example: sample 10 random keyword-prompt pairs
const sample = randomSample(kwdPrompts, 400);

// %% [markdown]
// # Test audit

// %%
let samplePrompts = sample.map(s => s.prompt);

start = Date.now();

const auditResults = await audit({
	prompts: samplePrompts,
	models: config.models,
	brand: cached.brand,
	competitors: cached.competitors,
	useSearch: true,
});

duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`Audit completed in ${duration}s\n`)
console.log(`Results: ${auditResults.length} search results with flagged sources\n`);
// Out:
// Audit completed in 32.5s
//
// Results: 400 search results with flagged sources

// %%
console.log(JSON.stringify(auditResults[0], null, 2));
// Out:
// {
//   "answer": "Los coches de hidrógeno, aunque ofrecen ventajas como cero emisiones y tiempos de repostaje rápidos, suelen tener precios más elevados que los vehículos convencionales. En Estados Unidos, el modelo más destacado es el Toyota Mirai, que en 2024 tenía un precio base de 67.095 dólares en California. ([electrive.com](https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai)) Sin embargo, debido a las bajas ventas, Toyota ha implementado descuentos significativos, llegando hasta 40.000 dólares en algunas regiones, reduciendo el precio final a aproximadamente 27.095 dólares. ([electrive.com](https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai))\n\nAdemás de los descuentos, Toyota ofrece incentivos adicionales, como 15.000 dólares en combustible de hidrógeno durante seis años, lo que puede ser atractivo para los consumidores. ([motor16.com](https://www.motor16.com/electrico/toyota-mirai-pone-punto-estados-unidos/?utm_source=openai))\n\nEs importante considerar que el precio del hidrógeno en Estados Unidos varía según la ubicación y el método de producción. En promedio, oscila entre 29 y 36 dólares por kilogramo. Un vehículo típico de pila de combustible de hidrógeno puede recorrer aproximadamente 96-112 kilómetros por kilogramo de hidrógeno. Por lo tanto, llenar un vehículo con 5-6 kg de hidrógeno (suficiente para una autonomía de 480-640 kilómetros) podría costar entre 150 y 180 dólares. ([glpautogas.info](https://www.glpautogas.info/es/precio-hidrogeno-estados-unidos.html?utm_source=openai))\n\nEn resumen, aunque los coches de hidrógeno tienen precios más altos que los vehículos tradicionales, los descuentos y subsidios actuales pueden hacerlos más accesibles para los consumidores interesados en esta tecnología. ",
//   "sources": [
//     {
//       "title": "Toyota opta por las rebajas masivas en los coches de hidrógeno en EE.UU. - electrive.com",
//       "url": "https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai",
//       "domain": "electrive.com",
//       "mentionedBrands": [],
//       "mentionedCompetitors": [],
//       "linkedBrand": null,
//       "linkedCompetitor": null
//     },
//     {
//       "title": "Toyota opta por las rebajas masivas en los coches de hidrógeno en EE.UU. - electrive.com",
//       "url": "https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai",
//       "domain": "electrive.com",
//       "mentionedBrands": [],
//       "mentionedCompetitors": [],
//       "linkedBrand": null,
//       "linkedCompetitor": null
//     },
//     {
//       "title": "El Toyota Mirai se pone a punto en Estados Unidos",
//       "url": "https://www.motor16.com/electrico/toyota-mirai-pone-punto-estados-unidos/?utm_source=openai",
//       "domain": "motor16.com",
//       "mentionedBrands": [],
//       "mentionedCompetitors": [],
//       "linkedBrand": null,
//       "linkedCompetitor": null
//     },
//     {
//       "title": "Precio hidrógeno Estados Unidos. Actualizado",
//       "url": "https://www.glpautogas.info/es/precio-hidrogeno-estados-unidos.html?utm_source=openai",
//       "domain": "glpautogas.info",
//       "mentionedBrands": [],
//       "mentionedCompetitors": [],
//       "linkedBrand": null,
//       "linkedCompetitor": null
//     }
//   ],
//   "prompt": "¿Cuánto cuestan los coches de hidrógeno?",
//   "model": "gpt_4_1_mini",
//   "rankedBrandsInAnswer": [],
//   "rankedBrandsInSourceTitles": [],
//   "rankedBrandsInSourceDomains": []
// }

// %%
// Join keywords with audit
let joined = sample.map((kwd: any, index: number) => ({
    ...kwd,
    ...auditResults[index]
}));

// %%
joined[1]
// Out:
// {
//   ROWID: 1381,
//   keyword: "peugeot 108 diesel",
//   avgMonthlySearches: 20,
//   competition: "HIGH",
//   competitionIndex: 96,
//   averageCpc: 0.8115630149841309,
//   lowTopOfPageBid: 0.162650004029274,
//   highTopOfPageBid: 0.8118169903755188,
//   searchVolume: [
//     20, 20, 20, 20, 20,
//     20, 20, 20, 20, 10,
//     20, 20
//   ],
//   searchVolumeDate: [
//     "2024-10-01T00:00:00.000Z",
//     "2024-11-01T00:00:00.000Z",
//     "2024-12-01T00:00:00.000Z",
//     "2025-01-01T00:00:00.000Z",
//     "2025-02-01T00:00:00.000Z",
//     "2025-03-01T00:00:00.000Z",
//     "2025-04-01T00:00:00.000Z",
//     "2025-05-01T00:00:00.000Z",
//     "2025-06-01T00:00:00.000Z",
//     "2025-07-01T00:00:00.000Z",
//     "2025-08-01T00:00:00.000Z",
//     "2025-09-01T00:00:00.000Z"
//   ],
//   searchVolumeGrowthYoy: 0,
//   searchVolumeGrowth3m: 100,
//   searchVolumeGrowth1m: 0,
//   searchVolumeTrend: -0.01276983879506588,
//   concepts: [ "motor", "peugeot 108", "diesel" ],
//   conceptGroups: [ "Pieza Del Vehículo", "Modelo", "Otros" ],
//   prompt: "¿Existe una versión diesel del Peugeot 108?",
//   answer: "No, el Peugeot 108 no está disponible con motorización diésel. Este modelo se ofrece únicamente con motores de gasolina, específicamente con un motor 1.0 VTi de 68 CV y un motor 1.2 PureTech de 82 CV. ([motorpasion.com](https://www.motorpasion.com/pruebas-de-coches/peugeot-108-toma-de-contacto?utm_source=openai)) Además, el Peugeot 108 dejó de producirse en enero de 2022. ([en.wikipedia.org](https://en.wikipedia.org/wiki/Peugeot_108?utm_source=openai)) ",
//   sources: [
//     {
//       title: "Peugeot 108, toma de contacto",
//       url: "https://www.motorpasion.com/pruebas-de-coches/peugeot-108-toma-de-contacto?utm_source=openai",
//       domain: "motorpasion.com",
//       mentionedBrands: [ "Peugeot" ],
//       mentionedCompetitors: [],
//       linkedBrand: null,
//       linkedCompetitor: null
//     },
//     {
//       title: "Peugeot 108",
//       url: "https://en.wikipedia.org/wiki/Peugeot_108?utm_source=openai",
//       domain: "wikipedia.org",
//       mentionedBrands: [ "Peugeot" ],
//       mentionedCompetitors: [],
//       linkedBrand: null,
//       linkedCompetitor: null
//     }
//   ],
//   model: "gpt_4_1_mini",
//   rankedBrandsInAnswer: [ "Peugeot" ],
//   rankedBrandsInSourceTitles: [ "Peugeot" ],
//   rankedBrandsInSourceDomains: []
// }

// %%
await Deno.writeTextFile("./audit.json", JSON.stringify(joined, null, 2));

// %% [markdown]
// # Enrich audit

// %%
// Dynamically re-import enrichAudit
const { enrichAudit: enrichAuditFresh } = await import("../src/audit.ts");

const cached = JSON.parse(await Deno.readTextFile("./cache.json"));
const result = JSON.parse(await Deno.readTextFile("./audit.json"));
const enrichedAudit = await enrichAuditFresh(result, cached.funnel, cached.personas);
// Out:
// askOpenAISafe retrying! Previous attempt 1 failed with: Previous attempt failed with error: [
//   {
//     "code": "custom",
//     "message": "Subtopic 'Product / Microsite' is not a valid subtopic for topic 'Commercial'. Allowed subtopics are: E-Commerce / Retailer, Marketplace, Affiliate / Comparison Site, Classifieds / Listings, Travel / Booking Platform, Job Board / Recruitment.",
//     "path": [
//       "subtopic"
//     ]
//   }
// ]
// Identifying topics...
// Assigning topics...
// askOpenAISafe retrying! Previous attempt 1 failed with: Previous attempt failed with error: [
//   {
//     "code": "custom",
//     "message": "Subtopic 'Cita y atención al cliente' is not a valid subtopic for topic 'Peugeot'. Allowed subtopics are: Modelos Peugeot eléctricos, Modelos Peugeot híbridos, Modelos Peugeot convencionales, Servicios y mantenimiento Peugeot, Accesorios y repuestos Peugeot.",
//     "path": [
//       "subtopic"
//     ]
//   }
// ]
// Assigning funnel stages...
// Classifying prompts into personas...
// Classifying prompt intents...
// Classifying prompts into branded/non-branded...

// %%
enrichedAudit[0]
// Out:
// {
//   ROWID: 2291,
//   keyword: "coches de hidrógeno precio",
//   avgMonthlySearches: 50,
//   competition: "MEDIUM",
//   competitionIndex: 48,
//   averageCpc: 0.32190701365470886,
//   lowTopOfPageBid: 0.050508998334407806,
//   highTopOfPageBid: 0.7048799991607666,
//   searchVolume: [
//     50, 70, 50, 70, 90,
//     50, 50, 40, 50, 50,
//     20, 40
//   ],
//   searchVolumeDate: [
//     "2024-10-01T00:00:00.000Z",
//     "2024-11-01T00:00:00.000Z",
//     "2024-12-01T00:00:00.000Z",
//     "2025-01-01T00:00:00.000Z",
//     "2025-02-01T00:00:00.000Z",
//     "2025-03-01T00:00:00.000Z",
//     "2025-04-01T00:00:00.000Z",
//     "2025-05-01T00:00:00.000Z",
//     "2025-06-01T00:00:00.000Z",
//     "2025-07-01T00:00:00.000Z",
//     "2025-08-01T00:00:00.000Z",
//     "2025-09-01T00:00:00.000Z"
//   ],
//   searchVolumeGrowthYoy: -20,
//   searchVolumeGrowth3m: -20,
//   searchVolumeGrowth1m: 100,
//   searchVolumeTrend: -0.053946055471897125,
//   concepts: [ "carros" ],
//   conceptGroups: [ "No-Marcas", "Otros" ],
//   prompt: "¿Cuánto cuestan los coches de hidrógeno?",
//   answer: "Los coches de hidrógeno, aunque ofrecen ventajas como cero emisiones y tiempos de repostaje rápidos, suelen tener precios más elevados que los vehículos convencionales. En Estados Unidos, el modelo más destacado es el Toyota Mirai, que en 2024 tenía un precio base de 67.095 dólares en California. ([electrive.com](https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai)) Sin embargo, debido a las bajas ventas, Toyota ha implementado descuentos significativos, llegando hasta 40.000 dólares en algunas regiones, reduciendo el precio final a aproximadamente 27.095 dólares. ([electrive.com](https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai))\n" +
//     "\n" +
//     "Además de los descuentos, Toyota ofrece incentivos adicionales, como 15.000 dólares en combustible de hidrógeno durante seis años, lo que puede ser atractivo para los consumidores. ([motor16.com](https://www.motor16.com/electrico/toyota-mirai-pone-punto-estados-unidos/?utm_source=openai))\n" +
//     "\n" +
//     "Es importante considerar que el precio del hidrógeno en Estados Unidos varía según la ubicación y el método de producción. En promedio, oscila entre 29 y 36 dólares por kilogramo. Un vehículo típico de pila de combustible de hidrógeno puede recorrer aproximadamente 96-112 kilómetros por kilogramo de hidrógeno. Por lo tanto, llenar un vehículo con 5-6 kg de hidrógeno (suficiente para una autonomía de 480-640 kilómetros) podría costar entre 150 y 180 dólares. ([glpautogas.info](https://www.glpautogas.info/es/precio-hidrogeno-estados-unidos.html?utm_source=openai))\n" +
//     "\n" +
//     "En resumen, aunque los coches de hidrógeno tienen precios más altos que los vehículos tradicionales, los descuentos y subsidios actuales pueden hacerlos más accesibles para los consumidores interesados en esta tecnología. ",
//   sources: [
//     {
//       title: "Toyota opta por las rebajas masivas en los coches de hidrógeno en EE.UU. - electrive.com",
//       url: "https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai",
//       domain: "electrive.com",
//       mentionedBrands: [],
//       mentionedCompetitors: [],
//       linkedBrand: null,
//       linkedCompetitor: null,
//       category: "News & Media",
//       subcategory: "Trade / Niche Publication"
//     },
//     {
//       title: "Toyota opta por las rebajas masivas en los coches de hidrógeno en EE.UU. - electrive.com",
//       url: "https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai",
//       domain: "electrive.com",
//       mentionedBrands: [],
//       mentionedCompetitors: [],
//       linkedBrand: null,
//       linkedCompetitor: null,
//       category: "News & Media",
//       subcategory: "Trade / Niche Publication"
//     },
//     {
//       title: "El Toyota Mirai se pone a punto en Estados Unidos",
//       url: "https://www.motor16.com/electrico/toyota-mirai-pone-punto-estados-unidos/?utm_source=openai",
//       domain: "motor16.com",
//       mentionedBrands: [],
//       mentionedCompetitors: [],
//       linkedBrand: null,
//       linkedCompetitor: null,
//       category: "News & Media",
//       subcategory: "Trade / Niche Publication"
//     },
//     {
//       title: "Precio hidrógeno Estados Unidos. Actualizado",
//       url: "https://www.glpautogas.info/es/precio-hidrogeno-estados-unidos.html?utm_source=openai",
//       domain: "glpautogas.info",
//       mentionedBrands: [],
//       mentionedCompetitors: [],
//       linkedBrand: null,
//       linkedCompetitor: null,
//       category: "Reference & Knowledge",
//       subcategory: "Data / Statistics Portal"
//     }
//   ],
//   model: "gpt_4_1_mini",
//   rankedBrandsInAnswer: [],
//   rankedBrandsInSourceTitles: [],
//   rankedBrandsInSourceDomains: [],
//   topic: "Precios y financiación",
//   subtopic: "Precios de coches eléctricos e híbridos",
//   funnelStage: "Decisión / Evaluación",
//   funnelCategory: "Precios & Ofertas",
//   personas: [
//     "Joven Profesional Eco-Consciente",
//     "Amante de la Tecnología y la Innovación"
//   ],
//   intent: "informational",
//   isBranded: "non-branded"
// }

// %%
await Deno.writeTextFile("./audit.json", JSON.stringify(enrichedAudit, null, 2));

// %% [markdown]
// # More enrichments

// %%
const result = JSON.parse(await Deno.readTextFile("./audit.json"));

// %%
start = Date.now();

const answers = result.map((response: Record<string, unknown>) => response.answer);
const abss = await extractABSForBrandBatch(answers, cached.brand, 'gpt-4.1');

duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`\n✅ Extracted aspect-based sentiments for ${abss.length} texts in ${duration}s\n`);
// Out:
// ✅ Extracted aspect-based sentiments for 400 texts in 20.2s

// %%
abss[2]
// Out:
// []

// %%
import { extractEntitiesBatch } from "../src/entities.ts";

const entityDefinitions = {
    "brands": "Any brand or companies mentioned",
    "products": "Any products or services mentioned",
    "features": "Specific features or attributes of products/services",
    "issues": "Problems or issues mentioned",
}

start = Date.now();

const answers = result.map((response: Record<string, unknown>) => response.answer);
const entities = await extractEntitiesBatch(answers, entityDefinitions, 'gpt-4.1');

duration = ((Date.now() - start) / 1000).toFixed(1);
console.log(`\n✅ Extracted entities for ${entities.length} texts in ${duration}s\n`);
// Out:
// ✅ Extracted entities for 400 texts in 28.7s

// %%
entities[0]
// Out:
// [
//   { name: "toyota", type: "brand" },
//   { name: "mirai", type: "product" },
//   { name: "hidrógeno", type: "product" },
//   { name: "coche de hidrógeno", type: "product" },
//   { name: "vehículo convencional", type: "product" },
//   { name: "pila de combustible de hidrógeno", type: "product" },
//   { name: "emisión cero", type: "feature" },
//   { name: "tiempo de repostaje rápido", type: "feature" },
//   { name: "precio elevado", type: "issue" },
//   { name: "baja venta", type: "issue" },
//   { name: "precio del hidrógeno alto", type: "issue" }
// ]

// %%
// Add sentiment and entity enrichment to audit results
result.forEach((r, i) => {
    r.sentiments = abss[i];
    r.entities = entities[i];
});

await Deno.writeTextFile("./audit.json", JSON.stringify(result, null, 2));

// %% [markdown]
// # Read audit parquet

// %%
import { readParquetRows } from "./readParquetRows.ts";

const auditpqt = await readParquetRows<KeywordRecord>("./audit.parquet");
auditpqt[0]
// Out:
// {
//   ROWID: 2291n,
//   keyword: "coches de hidrógeno precio",
//   avgMonthlySearches: 50,
//   competition: "MEDIUM",
//   competitionIndex: 48,
//   averageCpc: 0.32190701365470803,
//   lowTopOfPageBid: 0.050508998334407,
//   highTopOfPageBid: 0.704879999160766,
//   searchVolume: {
//     list: [
//       { element: 50n },
//       { element: 70n },
//       { element: 50n },
//       { element: 70n },
//       { element: 90n },
//       { element: 50n },
//       { element: 50n },
//       { element: 40n },
//       { element: 50n },
//       { element: 50n },
//       { element: 20n },
//       { element: 40n }
//     ]
//   },
//   searchVolumeDate: {
//     list: [
//       { element: 2024-10-01T00:00:00.000Z },
//       { element: 2024-11-01T00:00:00.000Z },
//       { element: 2024-12-01T00:00:00.000Z },
//       { element: 2025-01-01T00:00:00.000Z },
//       { element: 2025-02-01T00:00:00.000Z },
//       { element: 2025-03-01T00:00:00.000Z },
//       { element: 2025-04-01T00:00:00.000Z },
//       { element: 2025-05-01T00:00:00.000Z },
//       { element: 2025-06-01T00:00:00.000Z },
//       { element: 2025-07-01T00:00:00.000Z },
//       { element: 2025-08-01T00:00:00.000Z },
//       { element: 2025-09-01T00:00:00.000Z }
//     ]
//   },
//   searchVolumeGrowthYoy: -20,
//   searchVolumeGrowth3m: -20,
//   searchVolumeGrowth1m: 100,
//   searchVolumeTrend: -0.05394605547189701,
//   concepts: { list: [ { element: "carros" } ] },
//   conceptGroups: { list: [ { element: "No-Marcas" }, { element: "Otros" } ] },
//   prompt: "¿Cuánto cuestan los coches de hidrógeno?",
//   answer: "Los coches de hidrógeno, aunque ofrecen ventajas como cero emisiones y tiempos de repostaje rápidos, suelen tener precios más elevados que los vehículos convencionales. En Estados Unidos, el modelo más destacado es el Toyota Mirai, que en 2024 tenía un precio base de 67.095 dólares en California. ([electrive.com](https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai)) Sin embargo, debido a las bajas ventas, Toyota ha implementado descuentos significativos, llegando hasta 40.000 dólares en algunas regiones, reduciendo el precio final a aproximadamente 27.095 dólares. ([electrive.com](https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai))\n" +
//     "\n" +
//     "Además de los descuentos, Toyota ofrece incentivos adicionales, como 15.000 dólares en combustible de hidrógeno durante seis años, lo que puede ser atractivo para los consumidores. ([motor16.com](https://www.motor16.com/electrico/toyota-mirai-pone-punto-estados-unidos/?utm_source=openai))\n" +
//     "\n" +
//     "Es importante considerar que el precio del hidrógeno en Estados Unidos varía según la ubicación y el método de producción. En promedio, oscila entre 29 y 36 dólares por kilogramo. Un vehículo típico de pila de combustible de hidrógeno puede recorrer aproximadamente 96-112 kilómetros por kilogramo de hidrógeno. Por lo tanto, llenar un vehículo con 5-6 kg de hidrógeno (suficiente para una autonomía de 480-640 kilómetros) podría costar entre 150 y 180 dólares. ([glpautogas.info](https://www.glpautogas.info/es/precio-hidrogeno-estados-unidos.html?utm_source=openai))\n" +
//     "\n" +
//     "En resumen, aunque los coches de hidrógeno tienen precios más altos que los vehículos tradicionales, los descuentos y subsidios actuales pueden hacerlos más accesibles para los consumidores interesados en esta tecnología. ",
//   sources: {
//     list: [
//       {
//         element: {
//           category: "News & Media",
//           domain: "electrive.com",
//           linkedBrand: null,
//           linkedCompetitor: null,
//           mentionedBrands: [Object],
//           mentionedCompetitors: [Object],
//           subcategory: "Trade / Niche Publication",
//           title: "Toyota opta por las rebajas masivas en los coches de hidrógeno en EE.UU. - electrive.com",
//           url: "https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai"
//         }
//       },
//       {
//         element: {
//           category: "News & Media",
//           domain: "electrive.com",
//           linkedBrand: null,
//           linkedCompetitor: null,
//           mentionedBrands: [Object],
//           mentionedCompetitors: [Object],
//           subcategory: "Trade / Niche Publication",
//           title: "Toyota opta por las rebajas masivas en los coches de hidrógeno en EE.UU. - electrive.com",
//           url: "https://www.electrive.com/es/2024/02/27/toyota-opta-por-rebajas-masivas-para-los-coches-de-hidrogeno-en-ee-uu/?utm_source=openai"
//         }
//       },
//       {
//         element: {
//           category: "News & Media",
//           domain: "motor16.com",
//           linkedBrand: null,
//           linkedCompetitor: null,
//           mentionedBrands: [Object],
//           mentionedCompetitors: [Object],
//           subcategory: "Trade / Niche Publication",
//           title: "El Toyota Mirai se pone a punto en Estados Unidos",
//           url: "https://www.motor16.com/electrico/toyota-mirai-pone-punto-estados-unidos/?utm_source=openai"
//         }
//       },
//       {
//         element: {
//           category: "Reference & Knowledge",
//           domain: "glpautogas.info",
//           linkedBrand: null,
//           linkedCompetitor: null,
//           mentionedBrands: [Object],
//           mentionedCompetitors: [Object],
//           subcategory: "Data / Statistics Portal",
//           title: "Precio hidrógeno Estados Unidos. Actualizado",
//           url: "https://www.glpautogas.info/es/precio-hidrogeno-estados-unidos.html?utm_source=openai"
//         }
//       }
//     ]
//   },
//   model: "gpt_4_1_mini",
//   rankedBrandsInAnswer: { list: null },
//   rankedBrandsInSourceTitles: { list: null },
//   rankedBrandsInSourceDomains: { list: null },
//   topic: "Precios y financiación",
//   subtopic: "Precios de coches eléctricos e híbridos",
//   funnelStage: "Decisión / Evaluación",
//   funnelCategory: "Precios & Ofertas",
//   personas: {
//     list: [
//       { element: "Joven Profesional Eco-Consciente" },
//       { element: "Amante de la Tecnología y la Innovación" }
//     ]
//   },
//   intent: "informational",
//   isBranded: "non-branded",
//   sentiments: {
//     list: [
//       {
//         element: {
//           aspect: "coches de hidrógeno",
//           reason: "Se menciona que los coches de hidrógeno suelen tener precios más elevados que los vehículos convencionales, resaltando una característica negativa.",
//           sentiment: "negative"
//         }
//       },
//       {
//         element: {
//           aspect: "descuentos y subsidios actuales",
//           reason: "Los descuentos y subsidios actuales son presentados como algo que puede hacer los coches de hidrógeno más accesibles, lo que constituye una valoración positiva.",
//           sentiment: "positive"
//         }
//       },
//       {
//         element: {
//           aspect: "incentivos adicionales de Toyota",
//           reason: "Se menciona que los incentivos adicionales, como los 15.000 dólares en combustible, pueden ser atractivos para los consumidores, expresando una opinión positiva.",
//           sentiment: "positive"
//         }
//       },
//       {
//         element: {
//           aspect: "precio del hidrógeno",
//           reason: "El texto señala que el costo de llenar el depósito de un vehículo de hidrógeno podría ser de 150 a 180 dólares, lo cual resulta una carga económica y por tanto es una valoración negativa.",
//           sentiment: "negative"
//         }
//       }
//     ]
//   },
//   entities: {
//     list: [
//       { element: { name: "toyota", type: "brand" } },
//       { element: { name: "mirai", type: "product" } },
//       { element: { name: "hidrógeno", type: "product" } },
//       { element: { name: "coche de hidrógeno", type: "product" } },
//       { element: { name: "vehículo convencional", type: "product" } },
//       {
//         element: { name: "pila de combustible de hidrógeno", type: "product" }
//       },
//       { element: { name: "emisión cero", type: "feature" } },
//       {
//         element: { name: "tiempo de repostaje rápido", type: "feature" }
//       },
//       { element: { name: "precio elevado", type: "issue" } },
//       { element: { name: "baja venta", type: "issue" } },
//       { element: { name: "precio del hidrógeno alto", type: "issue" } }
//     ]
//   }
// }

// %%
auditpqt[0].searchVolume[0]

// %%
auditpqt[0].searchVolumeDate.list[0].element
// Out:
// 2024-10-01T00:00:00.000Z

// %% [markdown]
// # Google Autocomplete

// %%
import { autocomplete, autocompleteSafe, recurseAutocomplete } from "../src/autocomplete.ts";

// %%
await autocompleteSafe({query: "coches eléctricos", countryCode: "ES", language: "es"});
// Out:
// [
//   "coches eléctricos segunda mano",
//   "coches eléctricos chinos",
//   "coches eléctricos con mayor autonomía",
//   "coches eléctricos precios",
//   "coches electricos pequeños",
//   "coches eléctricos toyota",
//   "coches eléctricos alquiler madrid",
//   "coches eléctricos byd",
//   "coches eléctricos chinos baratos",
//   "coches electricos niños",
//   "coches electricos para niños",
//   "coches eléctricos para niños 24v baratos",
//   "coches eléctricos sin carnet",
//   "coches eléctricos más baratos",
//   "coches eléctricos madrid"
// ]

// %%
let suggestions = await recurseAutocomplete({
    query: "coches eléctricos",
    countryCode: "ES",
    language: "es",
    maxDepth: 2,
    delayBetweenCalls: 1000
});

suggestions
// Out:
// [
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos segunda mano",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos chinos",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos con mayor autonomía",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos precios",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches electricos pequeños",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos toyota",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos alquiler madrid",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos byd",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos chinos baratos",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches electricos niños",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches electricos para niños",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos para niños 24v baratos",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos sin carnet",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos más baratos",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos",
//     suggestion: "coches eléctricos madrid",
//     depth: 0
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano madrid",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano alemania",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano milanuncios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano mallorca",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano barcelona",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano valencia",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano galicia",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano tenerife",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches electricos segunda mano canarias",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches eléctricos segunda mano las palmas",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches electricos segunda mano malaga",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches electricos segunda mano asturias",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches electricos segunda mano niños",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches electricos segunda mano murcia",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos segunda mano",
//     suggestion: "coches electricos segunda mano alicante",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos baratos",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos marcas",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos byd",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches electricos chinos pequeños",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos de alta gama",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos 2025",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos xiaomi",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches electricos chinos en españa precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos segunda mano",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos en canarias",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos chinos",
//     suggestion: "coches eléctricos chinos en méxico",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con mayor autonomía 2025",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con mayor autonomía real",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con mayor autonomía 2024",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con mayor autonomía del mercado",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos pequeños con mayor autonomía",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos chinos con mayor autonomía",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos baratos con mayor autonomía",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "mejores coches electricos con mayor autonomia",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con mayor autonomía 2021",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con mayor autonomía 2022",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con más autonomia",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos con mayor autonomía",
//     suggestion: "coches eléctricos con mayor autonomía 2023",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches eléctricos precios y autonomía",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches electricos precios españa",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches eléctricos precios 2024",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches electricos precios 2025",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches electricos precios baratos",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "cargadores coches eléctricos precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches electricos byd precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches eléctricos chinos precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches electricos kia precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches mg electricos precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches eléctricos 4x4 precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches eléctricos pequeños precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches electricos renault precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches eléctricos tesla precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos precios",
//     suggestion: "coches electricos volkswagen precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños baratos",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños segunda mano",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños para ciudad",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños chinos",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños 5 plazas",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños españa",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños 2026",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches eléctricos pequeños precios",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños ciudad",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches electricos pequeños",
//     suggestion: "coches electricos pequeños en mexico",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "coches electricos toyota 2025",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "coches electricos toyota 2024",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "coches electricos toyota 2026",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "coches electricos niños toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "proximos coches electricos toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "nuevos coches electricos toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "baterias coches electricos toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "coches electricos baratos toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "gama coches eléctricos toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "renting coches electricos toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "cuantos coches electricos tiene toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos toyota",
//     suggestion: "qué coches eléctricos tiene toyota",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "coches electricos madrid alquiler emov",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "precio coches electricos alquiler madrid",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "alquiler coches eléctricos madrid zity",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "alquiler coches electricos madrid por horas",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "app alquiler coches electricos madrid",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "empresas alquiler coches electricos madrid",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "alquiler coches electricos niños madrid",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "alquiler coches electricos ayuntamiento de madrid",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "coches eléctricos madrid app",
//     depth: 1
//   },
//   {
//     sourceQuery: "coches eléctricos alquiler madrid",
//     suggestion: "coches eléctricos madrid",
//     depth: 1
//   },
//   ... 100 more items
// ]

// %%
const uniqueSuggestions = [...new Set(suggestions.map(s => s.suggestion))];
console.log(uniqueSuggestions.length);
console.log(JSON.stringify(uniqueSuggestions, null, 2));
// Out:
// 189
// [
//   "coches eléctricos segunda mano",
//   "coches eléctricos chinos",
//   "coches eléctricos con mayor autonomía",
//   "coches eléctricos precios",
//   "coches electricos pequeños",
//   "coches eléctricos toyota",
//   "coches eléctricos alquiler madrid",
//   "coches eléctricos byd",
//   "coches eléctricos chinos baratos",
//   "coches electricos niños",
//   "coches electricos para niños",
//   "coches eléctricos para niños 24v baratos",
//   "coches eléctricos sin carnet",
//   "coches eléctricos más baratos",
//   "coches eléctricos madrid",
//   "coches eléctricos segunda mano madrid",
//   "coches eléctricos segunda mano alemania",
//   "coches eléctricos segunda mano milanuncios",
//   "coches eléctricos segunda mano mallorca",
//   "coches eléctricos segunda mano barcelona",
//   "coches eléctricos segunda mano valencia",
//   "coches eléctricos segunda mano galicia",
//   "coches eléctricos segunda mano tenerife",
//   "coches electricos segunda mano canarias",
//   "coches eléctricos segunda mano las palmas",
//   "coches electricos segunda mano malaga",
//   "coches electricos segunda mano asturias",
//   "coches electricos segunda mano niños",
//   "coches electricos segunda mano murcia",
//   "coches electricos segunda mano alicante",
//   "coches eléctricos chinos marcas",
//   "coches eléctricos chinos byd",
//   "coches electricos chinos pequeños",
//   "coches eléctricos chinos de alta gama",
//   "coches eléctricos chinos 2025",
//   "coches eléctricos chinos xiaomi",
//   "coches electricos chinos en españa precios",
//   "coches eléctricos chinos segunda mano",
//   "coches eléctricos chinos en canarias",
//   "coches eléctricos chinos en méxico",
//   "coches eléctricos con mayor autonomía 2025",
//   "coches eléctricos con mayor autonomía real",
//   "coches eléctricos con mayor autonomía 2024",
//   "coches eléctricos con mayor autonomía del mercado",
//   "coches eléctricos pequeños con mayor autonomía",
//   "coches eléctricos chinos con mayor autonomía",
//   "coches eléctricos baratos con mayor autonomía",
//   "mejores coches electricos con mayor autonomia",
//   "coches eléctricos con mayor autonomía 2021",
//   "coches eléctricos con mayor autonomía 2022",
//   "coches eléctricos con más autonomia",
//   "coches eléctricos con mayor autonomía 2023",
//   "coches eléctricos precios y autonomía",
//   "coches electricos precios españa",
//   "coches eléctricos precios 2024",
//   "coches electricos precios 2025",
//   "coches electricos precios baratos",
//   "cargadores coches eléctricos precios",
//   "coches electricos byd precios",
//   "coches eléctricos chinos precios",
//   "coches electricos kia precios",
//   "coches mg electricos precios",
//   "coches eléctricos 4x4 precios",
//   "coches eléctricos pequeños precios",
//   "coches electricos renault precios",
//   "coches eléctricos tesla precios",
//   "coches electricos volkswagen precios",
//   "coches electricos pequeños baratos",
//   "coches electricos pequeños segunda mano",
//   "coches electricos pequeños para ciudad",
//   "coches electricos pequeños chinos",
//   "coches electricos pequeños 5 plazas",
//   "coches electricos pequeños españa",
//   "coches electricos pequeños 2026",
//   "coches electricos pequeños ciudad",
//   "coches electricos pequeños en mexico",
//   "coches electricos toyota 2025",
//   "coches electricos toyota 2024",
//   "coches electricos toyota 2026",
//   "coches electricos niños toyota",
//   "proximos coches electricos toyota",
//   "nuevos coches electricos toyota",
//   "baterias coches electricos toyota",
//   "coches electricos baratos toyota",
//   "gama coches eléctricos toyota",
//   "renting coches electricos toyota",
//   "cuantos coches electricos tiene toyota",
//   "qué coches eléctricos tiene toyota",
//   "coches electricos madrid alquiler emov",
//   "precio coches electricos alquiler madrid",
//   "alquiler coches eléctricos madrid zity",
//   "alquiler coches electricos madrid por horas",
//   "app alquiler coches electricos madrid",
//   "empresas alquiler coches electricos madrid",
//   "alquiler coches electricos niños madrid",
//   "alquiler coches electricos ayuntamiento de madrid",
//   "coches eléctricos madrid app",
//   "coches eléctricos byd precio",
//   "coches eléctricos byd dolphin",
//   "coches electricos byd opiniones",
//   "coches electricos byd seal",
//   "coches electricos byd en españa",
//   "coches eléctricos byd dolphin surf",
//   "coches eléctricos byd segunda mano",
//   "coches electricos byd autonomia",
//   "marca coches electricos byd",
//   "coches electricos baratos byd",
//   "coches electricos chinos byd precios",
//   "renting coches electricos byd",
//   "nuevos coches eléctricos byd",
//   "coches eléctricos chinos baratos en españa",
//   "coches electricos niños madrid",
//   "coches electricos niños 2 plazas",
//   "coches electricos niños amazon",
//   "coches electricos niños toysrus",
//   "coches electricos niños baratos",
//   "coches electricos niños 5 años",
//   "coches electricos niños opiniones",
//   "coches electricos niños 2 años",
//   "coches electricos niños mercedes",
//   "coches eléctricos niños segunda mano",
//   "coches electricos niños juguettos",
//   "coches electricos niños valencia",
//   "coches electricos niños sevilla",
//   "coches electricos niños barcelona",
//   "coches electricos niños murcia",
//   "coches electricos para niños 48v segunda mano",
//   "coches electricos para niños de 1 año",
//   "coches electricos para niños de 3 a 8 años",
//   "coches eléctricos para niños de 5 años",
//   "coches electricos para niños cerca",
//   "coches eléctricos para niños 24v carrefour",
//   "coches eléctricos para niños 48v",
//   "coches eléctricos para niños de 7 a 8 años",
//   "coches eléctricos para niños 24v",
//   "coches eléctricos para niños 24v baratos amazon",
//   "coches eléctricos para niños baratos",
//   "coches eléctricos para niños 24v baratos segunda mano",
//   "coches eléctricos para niños de 10 años",
//   "coches eléctricos para niños pequeños",
//   "coches eléctricos para niños 24v baratos wallapop",
//   "coches eléctricos para niños 24v baratos carrefour",
//   "coches eléctricos para niños 24v baratos cerca",
//   "todoterreno coches eléctricos para niños 24v baratos",
//   "camión coches eléctricos para niños 24v baratos",
//   "bmw coches eléctricos para niños 24v baratos",
//   "buggy y utv coches eléctricos para niños 24v baratos",
//   "coches electricos para niños baratos 6 12 y 24v",
//   "coches eléctricos sin carnet 4 plazas",
//   "coches eléctricos sin carnet precios",
//   "coches eléctricos sin carnet segunda mano",
//   "coches eléctricos sin carnet de conducir",
//   "coches eléctricos sin carnet baratos",
//   "coches electricos sin carnet de conducir precios",
//   "coches electricos sin carnet españa",
//   "coches eléctricos sin carnet 2 plazas",
//   "coches eléctricos sin carnet renault",
//   "coches eléctricos pequeños sin carnet",
//   "coches electricos chinos sin carnet",
//   "mini coches eléctricos sin carnet",
//   "mejores coches electricos sin carnet",
//   "coches electricos para conducir sin carnet",
//   "coches eléctricos más baratos 2025",
//   "coches electricos mas baratos en españa",
//   "coches eléctricos más baratos españa 2025",
//   "coches eléctricos más baratos 2024",
//   "coches eléctricos más baratos segunda mano",
//   "coches eléctricos más baratos en méxico",
//   "coches eléctricos chinos más baratos",
//   "coches eléctricos nuevos más baratos",
//   "coches electricos baratos",
//   "coches eléctricos baratos segunda mano",
//   "coches eléctricos baratos 2024",
//   "coches electricos baratos españa",
//   "coches electricos baratos niños",
//   "coches electricos baratos con mas autonomia",
//   "coches eléctricos baratos para niños",
//   "coches eléctricos madrid alquiler",
//   "coches eléctricos madrid zity",
//   "coches electricos madrid central",
//   "coches electricos madrid centro",
//   "coches electricos madrid incendio",
//   "coches electricos madrid ayuntamiento",
//   "taller coches eléctricos madrid",
//   "renting coches electricos madrid",
//   "aplicacion coches electricos madrid",
//   "ayudas coches electricos madrid",
//   "feria coches electricos madrid",
//   "coches electricos parking madrid"
// ]
