// %% [markdown]
// # SEO visibility and content gap
//
// Given an AI visibility gap in a certain topic:
//
// - checks if this is due to missing content, or content not being indexed/positioned well by Google
//     - extracts (from datocat) or derives (with LLM) N google keywords relacionados con el cluster de prompts
//     - compares visibility in Google with competitors
//     - TODO: checks for additional (non-ranked) content using _branded_ keywords (e.g. ayudas coches eléctricos Peugeot)
// - checks own/competitor's web content that _is_ positioned
//     - deeply analyses competitor web content:
//         - presence of structured data, listicles, FAQs etc.
//         - entities mentioned
//         - internal and external linking
//     - TODO: compares with own brand content
//     - TODO: recommends content to create/modify
//
// ChatGPT context: https://chatgpt.com/share/6925a9d4-f81c-8005-8362-9ca5e8d57c4d

// %%
import { load } from "@std/dotenv";

import * as pl from "npm:nodejs-polars";
import * as Plot from "npm:@observablehq/plot";
import { document } from "jsr:@manzt/jupyter-helper";
import { z } from '@zod/zod';

import { askOpenAISafe } from "shared/openai.ts";

import * as utils from "../../src/utils.ts?v=8";
import * as brands from "../../src/brands.ts?v=4";
import * as scrape from "../../src/apis/hasdata/scrape.ts?v=1";
import * as serp from "../../src/apis/hasdata/serp.ts?v=1";
import * as surfaceGap from "../../src/analysis/surfaceGap.ts?v=19";

void await load({
  envPath: "../../.env",
  export: true,
});

const CACHE = "./contentGap2.json"

// %%
const { md, html, display } = Deno.jupyter;

// %%
// await utils.clearCache(CACHE);

// %%
let CONFIG = {
    brandDomain: "peugeot.es",
    sector: "coches eléctricos y SUVs",
    country: "es",
    language: "es",
}

// %% [markdown]
// # Brand and competitors
//
// We will compare the "organic" visibility GAP across competitors.

// %%
let regenBrands = false;
let briefing = "Include at least these brands: Toyota, Tesla, Nissan, Renault, Hyundai, Kia, MG, BYD, Omoda, Volkswagen, BMW, Audi, Mercedes, Fiat, Opel, Citroën, Seat, Honda";

let brs = await utils.fromCache(CACHE, 'brands') as brands.FlaggedBrand[] | null;
if (!brs || regenBrands) {
    console.log('Generating brand data...');
    const brand = await brands.generateBrandInfo({
        brandDomain: CONFIG.brandDomain,
        language: CONFIG.language,
        sector: CONFIG.sector,
        market: CONFIG.country,
    });
    const competitors = await brands.generateCompetitorsInfo({
        brandDomain: CONFIG.brandDomain,
        language: CONFIG.language,
        sector: CONFIG.sector,
        market: CONFIG.country,
        briefing: briefing
    });
    brs = brands.concatBrands([brand], competitors);
    await utils.toCache(CACHE, brs, 'overwrite', 'brands');
} else {
    console.log('Loaded brand data from cache');
}
// Out:
// Loaded brand data from cache

// %%
brs.map(b => b.shortName)
// Out:
// [
//   "Peugeot",  "Toyota",
//   "Tesla",    "BYD",
//   "Hyundai",  "Kia",
//   "Renault",  "Volkswagen",
//   "BMW",      "Audi",
//   "Mercedes", "Honda",
//   "MG"
// ]

// %% [markdown]
// # Define topic queries
//
// Define or generate (with LLM) a number of search queries for the topic (or prompt cluster) we're investigating.

// %% [markdown]
// ## Generate

// %%
let regenQueries = false;

const nQueries = 50;
const queriesPrompt = `
Estoy investigando la visibilidad de una marca de coches en repuestas de LLMs y IAs (Google AI Overview and Mode, ChatGPT).
Sospecho que se posicionan mal (posiblemente por falta de contenido) en temas de subvenciones y ayudas estatales a las compras
de coches (especialmente eléctricos). También les interesa la visibilidad en este tema de los SUVs. Dame ${nQueries} prompts
relacionados con el tema que puedo usar para medir la visibilidad en IAs y para medir un posible content gap
`.trim();

let queries = await utils.fromCache(CACHE, 'queries');
if (!queries || regenQueries) {
    console.log('Generating topic queries...');
    queries = await surfaceGap.generateTopicQueries(
        queriesPrompt,
        nQueries,
        CONFIG.language
    );
    await utils.toCache(CACHE, queries, 'overwrite', 'queries');
}
else {
    console.log('Loaded queries from cache');
}
// Out:
// Loaded queries from cache

// %%
queries
// Out:
// [
//   "ayudas compra coche eléctrico",
//   "subvenciones coche nuevo 2025",
//   "plan moves coches eléctricos",
//   "incentivos fiscales vehículo eléctrico",
//   "descuentos estatales coches",
//   "ayudas coche híbrido enchufable",
//   "subvenciones renovación coche viejo",
//   "programas gobierno movilidad eléctrica",
//   "bonificaciones compra suv eléctrico",
//   "ayudas suv etiqueta cero",
//   "subvenciones suv etiqueta eco",
//   "incentivos compra suv híbrido",
//   "plan renove coches suvs",
//   "ayudas achatarramiento coche antiguo",
//   "subvenciones vehículo baja emisión",
//   "ayudas coche familiar eléctrico",
//   "ayudas estatales coche urbano",
//   "subvenciones coche segunda mano",
//   "financiación pública coche eléctrico",
//   "ayudas punto recarga doméstico",
//   "subvenciones instalación cargador coche",
//   "beneficios fiscales coche empresa",
//   "deducciones irpf coche eléctrico",
//   "impuestos reducidos coche eficiente",
//   "ayudas regionales coche eléctrico",
//   "subvenciones comunidad autónoma coche",
//   "ayudas municipales coche eléctrico",
//   "zonas bajas emisiones ayudas coche",
//   "ayudas cambiar diésel por eléctrico",
//   "subvenciones flotas suvs híbridos",
//   "ayudas taxi eléctrico suv",
//   "programas gobierno suv eléctrico",
//   "incentivos compra suv familiar",
//   "subvenciones coche eléctrico barato",
//   "ayudas coche eléctrico particular",
//   "subvenciones renting coche eléctrico",
//   "ayudas leasing suv eléctrico",
//   "programas achatarrar suv antiguo",
//   "bonificación impuesto matriculación suv",
//   "ventajas etiqueta cero suv",
//   "requisitos plan moves suv",
//   "requisitos ayudas coche eléctrico",
//   "plazo solicitud ayudas coche",
//   "documentación subvención compra coche",
//   "compatibilidad ayudas coche eléctrico",
//   "limitaciones precio ayudas coche",
//   "marcas más subvencionadas coches",
//   "marcas líderes suv eléctricos",
//   "marcas recomendadas ayudas coche",
//   "¿Que ayudas o subvenciones hay ahora mismo para comprar un coche eléctrico en España?",
//   "¿Cuáles son los requisitos del plan Moves para comprar un vehículo eléctrico?",
//   "¿Qué documentos necesito para solicitar la subvención al comprar un coche eléctrico?",
//   "¿Cuáles son las limitaciones de precio para las ayudas de vehículos eléctricos?",
//   "¿Cuáles son los plazos para solicitar la subvención después de comprar un coche eléctrico?",
//   "¿Qué cambios se esperan en las futuras subvenciones para vehículos eléctricos en España?",
//   "¿Cuáles son los SUV eléctricos que tienen más subvenciones en España en este momento?",
//   "¿Qué marcas de SUVs eléctricos tienen mejores subvenciones disponibles?",
//   "¿Qué SUV eléctrico ofrece la mejor relación entre precio final",
//   "autonomía y ayudas disponibles?",
//   "¿Cuál es la oferta actual de SUV eléctricos para particulares con las ayudas vigentes?",
//   "¿Cuáles son las diferencias entre las ayudas para un coche eléctrico nuevo y uno de ocasión?",
//   "¿Puedo financiar un coche eléctrico y aun así recibir la subvención?",
//   "¿Cuánto tarda en cobrarse la ayuda después de comprar un coche eléctrico?"
// ]

// %% [markdown]
// ## From keywords

// %%
let kwdPrompts = await utils.fromCache("./kwdPrompts.json");
let kwds = Object.keys(kwdPrompts) as string[];
let queries = Object.values(kwdPrompts) as string[];
queries
// Out:
// [
//   "¿Qué ayudas existen para comprar un coche eléctrico en España?",
//   "¿En qué consiste el Plan MOVES III y qué ayudas ofrece?",
//   "¿Qué ayudas hay actualmente para la compra de un coche eléctrico?",
//   "¿Qué subvenciones están disponibles para coches eléctricos?",
//   "¿Qué subvención puedo obtener para instalar un cargador de coche eléctrico?",
//   "¿Qué ayudas existen para comprar un coche híbrido?",
//   "¿Qué opciones de ayudas hay para comprar un coche eléctrico?",
//   "¿Qué ayudas existen para coches híbridos no enchufables?",
//   "¿Qué ayudas o subvenciones hay para instalar un cargador de coche eléctrico en casa?",
//   "¿Incluye el Plan MOVES III ayudas para híbridos no enchufables?",
//   "¿Qué ayudas están disponibles actualmente para coches híbridos?",
//   "¿Qué ayuda puedo solicitar para instalar un cargador de coche eléctrico?",
//   "¿Qué incluye el programa de ayudas MOVES III?",
//   "¿Qué ayudas ofrece el gobierno por comprar un coche híbrido?",
//   "¿Qué ayudas hay disponibles para vehículos eléctricos en general?",
//   "¿Qué ayudas da el gobierno para la compra de un coche eléctrico?",
//   "¿Qué incentivos existen por comprar un coche eléctrico?",
//   "¿Qué ofrece el Plan MOVES para híbridos enchufables?",
//   "¿Qué cubre exactamente el Plan MOVES 3?",
//   "¿Qué ayudas hay actualmente para coches eléctricos?",
//   "¿Qué ayuda puedo obtener para comprar un coche eléctrico?",
//   "¿Qué incentivos existen por comprar un coche híbrido?",
//   "¿Qué incentivos ofrece el gobierno por comprar un coche eléctrico?",
//   "¿Qué subvenciones hay disponibles para la compra de coches?",
//   "¿Qué incluye el programa de ayudas MOVES?",
//   "¿Cómo funcionan las ayudas del MOVES III?",
//   "¿Cuáles son las ayudas del Plan MOVES 3?",
//   "¿Qué ayudas existen ahora mismo para coches nuevos?",
//   "¿Qué ayudas están disponibles por comprar un coche eléctrico?",
//   "¿Qué ayudas existen para vehículos eléctricos?",
//   "¿Qué ayudas puedo solicitar para comprar un coche híbrido?",
//   "¿Cuáles son las nuevas ayudas para coches eléctricos?",
//   "¿Qué subvenciones ofrece el Plan MOVES III?"
// ]

// %% [markdown]
// # SERPs
//
// Given the search queries, get the SERPs and optionally expand with the PeopleAlsoAsk and RelatedQuestion components of the results.

// %%
let regenSerps = false;

let serps = await utils.fromCache(CACHE, 'serps') as Array<serp.SerpResponse> | null;
if (!serps || regenSerps) {
    console.log('Fetching Serps...');
    serps = await surfaceGap.serps(
        kwds,
        CONFIG.country,
        CONFIG.country,
        CONFIG.language
    );
    await utils.toCache(CACHE, serps, 'overwrite', 'serps');
}
else {
    console.log('Loaded Serps from cache');
}
// Out:
// Fetching Serps...

// %%
// TODO: Expand SERPs with relatedQuestions and PAA

// %% [markdown]
// # Scrape ChatGPT
//
// Repeat N times for better confidence

// %%
import * as gpt from "../../src/apis/brightdata.ts?v=2";
import type { ModelResult } from '../../src/schemas/models.schema.ts';

let regenGPT = false;
let gptResults = await utils.fromCache(CACHE, 'gptResults') as Array<ModelResult> | null;
if (!gptResults || regenGPT) {
    console.log('Fetching ChatGPT responses...');
    gptResults = await gpt.scrapeGPTBatch({
        prompts: queries,
        countryISOCode: CONFIG.country.toUpperCase(),
        useSearch: true,
    });
    await utils.toCache(CACHE, gptResults, 'overwrite', 'gptResults');
} else {
    console.log('Loaded ChatGPT responses from cache');
}
// Out:
// Fetching ChatGPT responses...

// %% [markdown]
// # Visibility (non-branded)
//
// Analyze visibility of brand and competitors in SERP organic results and AI Overview if available

// %%
let vis = await surfaceGap.visibility(serps, brs);
let visDf: pl.DataFrame = pl.readRecords(vis);

// %%
let gptVis = await surfaceGap.gptPresence(gptResults, brs);
let gptVisDf: pl.DataFrame = pl.readRecords(gptVis);

// %%
visDf
// Out:
// <table><thead><tr><th>name</th><th>organicCount</th><th>aioResponseCount</th><th>aioCitedCount</th></tr></thead><tbody><tr><td>Kia</td><td>18</td><td>0</td><td>30</td></tr><tr><td>Toyota</td><td>9</td><td>0</td><td>9</td></tr><tr><td>Renault</td><td>7</td><td>0</td><td>16</td></tr><tr><td>Tesla</td><td>3</td><td>0</td><td>0</td></tr><tr><td>Volkswagen</td><td>1</td><td>0</td><td>3</td></tr><tr><td>Peugeot</td><td>0</td><td>0</td><td>0</td></tr><tr><td>BYD</td><td>0</td><td>0</td><td>0</td></tr><tr><td>Hyundai</td><td>0</td><td>1</td><td>0</td></tr><tr><td>BMW</td><td>0</td><td>0</td><td>0</td></tr><tr><td>Audi</td><td>0</td><td>0</td><td>3</td></tr><tr><td>Mercedes</td><td>0</td><td>0</td><td>0</td></tr><tr><td>Honda</td><td>0</td><td>0</td><td>0</td></tr><tr><td>MG</td><td>0</td><td>0</td><td>0</td></tr></tbody></table>

// %%
let allVis = vis.map(v => {
    let gptV = gptVis.find(gv => gv.name === v.name);
    return {
        ...v,
        gptResponseCount: gptV ? gptV.gptResponseCount : 0,
        gptCitedCount: gptV ? gptV.gptCitedCount : 0,
        gptReferenceCount: gptV ? gptV.gptReferenceCount : 0,
    }
});

let allVisDf: pl.DataFrame = pl.readRecords(allVis);
await display(allVisDf);
allVisDf.select(pl.spearmanRankCorr("organicCount", "aioCitedCount"));
// Out:
// <table><thead><tr><th>name</th><th>organicCount</th><th>aioResponseCount</th><th>aioCitedCount</th><th>gptResponseCount</th><th>gptCitedCount</th><th>gptReferenceCount</th></tr></thead><tbody><tr><td>Kia</td><td>18</td><td>0</td><td>30</td><td>0</td><td>2</td><td>9</td></tr><tr><td>Toyota</td><td>9</td><td>0</td><td>9</td><td>0</td><td>13</td><td>18</td></tr><tr><td>Renault</td><td>7</td><td>0</td><td>16</td><td>1</td><td>3</td><td>8</td></tr><tr><td>Tesla</td><td>3</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>Volkswagen</td><td>1</td><td>0</td><td>3</td><td>0</td><td>0</td><td>6</td></tr><tr><td>Peugeot</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>BYD</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>Hyundai</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>BMW</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>Audi</td><td>0</td><td>0</td><td>3</td><td>0</td><td>1</td><td>2</td></tr><tr><td>Mercedes</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>Honda</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>MG</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table>
// <table><thead><tr><th>organicCount</th></tr></thead><tbody><tr><td>0.7942767628710199</td></tr></tbody></table>

// %%
// Calculate pairwise Spearman correlation matrix for all numeric columns (lower triangle, no diagonal)
let numericCols = ["organicCount", "aioResponseCount", "aioCitedCount", "gptResponseCount", "gptCitedCount", "gptReferenceCount"];

let corrMatrix: Array<{ col1: string; col2: string; correlation: number }> = [];
for (let i = 0; i < numericCols.length; i++) {
    for (let j = 0; j < numericCols.length; j++) {
        let corr = allVisDf
            .select(pl.spearmanRankCorr(numericCols[i], numericCols[j]))
            .row(0)[0] as number;
        if (true) {//(!Number.isNaN(corr)) {
            corrMatrix.push({
                col1: numericCols[j],
                col2: numericCols[i],
                correlation: corr
            });
        }
    }
}

let corrDf = pl.readRecords(corrMatrix).pivot({ on: "col2", index: "col1", values: "correlation" });
// await display(corrDf);

// Visualize as heatmap (lower triangle, no diagonal, skip NaN)
Plot.plot({
    document,
    marks: [
        Plot.cell(corrMatrix, {
            x: "col1",
            y: "col2",
            fill: "correlation",
            tip: true,
        }),
        Plot.text(corrMatrix, {
            x: "col1",
            y: "col2",
            text: d => d.correlation ? d.correlation.toFixed(2) : "",
            fill: d => Math.abs(d.correlation) > 0.5 ? "white" : "black",
            fontSize: 10,
        })
    ],
    color: {
        scheme: "RdBu",
        domain: [0, 1],
    },
    x: { tickRotate: -45, label: null, domain: numericCols },
    y: { label: null, domain: numericCols },
    title: "Spearman Rank Correlation Matrix",
    style: { backgroundColor: "white" },
    marginBottom: 80,
    marginLeft: 100,
});
// Out:
// <figure style="max-width:initial" class="plot-d6a7b5-figure"><h2>Spearman Rank Correlation Matrix</h2><svg style="background-color:white" viewBox="0 0 640 230" height="230" width="640" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
//   --plot-background: white;
//   display: block;
//   height: auto;
//   height: intrinsic;
//   max-width: 100%;
// }
// :where(.plot-d6a7b5 text),
// :where(.plot-d6a7b5 tspan) {
//   white-space: pre;
// }</style><g transform="translate(0,9.5)" stroke="currentColor" fill="none" aria-hidden="true" aria-label="y-axis tick"><path d="M0,0L-6,0" transform="translate(100,23)" /><path d="M0,0L-6,0" transform="translate(100,44)" /><path d="M0,0L-6,0" transform="translate(100,65)" /><path d="M0,0L-6,0" transform="translate(100,86)" /><path d="M0,0L-6,0" transform="translate(100,107)" /><path d="M0,0L-6,0" transform="translate(100,128)" /></g><g transform="translate(-9,9.5)" text-anchor="end" aria-label="y-axis tick label"><text transform="translate(100,23)" y="0.32em">organicCount</text><text transform="translate(100,44)" y="0.32em">aioResponseCount</text><text transform="translate(100,65)" y="0.32em">aioCitedCount</text><text transform="translate(100,86)" y="0.32em">gptResponseCount</text><text transform="translate(100,107)" y="0.32em">gptCitedCount</text><text transform="translate(100,128)" y="0.32em">gptReferenceCount</text></g><g transform="translate(38.5,0)" stroke="currentColor" fill="none" aria-hidden="true" aria-label="x-axis tick"><path d="M0,0L0,6" transform="translate(109,150)" /><path d="M0,0L0,6" transform="translate(194,150)" /><path d="M0,0L0,6" transform="translate(279,150)" /><path d="M0,0L0,6" transform="translate(364,150)" /><path d="M0,0L0,6" transform="translate(449,150)" /><path d="M0,0L0,6" transform="translate(534,150)" /></g><g transform="translate(38.5,11.82842712474619)" text-anchor="end" aria-label="x-axis tick label"><text transform="translate(109,150) rotate(-45)" y="0.32em">organicCount</text><text transform="translate(194,150) rotate(-45)" y="0.32em">aioResponseCount</text><text transform="translate(279,150) rotate(-45)" y="0.32em">aioCitedCount</text><text transform="translate(364,150) rotate(-45)" y="0.32em">gptResponseCount</text><text transform="translate(449,150) rotate(-45)" y="0.32em">gptCitedCount</text><text transform="translate(534,150) rotate(-45)" y="0.32em">gptReferenceCount</text></g><g aria-label="cell"><rect fill="rgb(5, 48, 97)" height="19" y="23" width="77" x="109" /><rect fill="rgb(35, 102, 165)" height="19" y="23" width="77" x="279" /><rect fill="rgb(160, 203, 226)" height="19" y="23" width="77" x="364" /><rect fill="rgb(51, 124, 182)" height="19" y="23" width="77" x="449" /><rect fill="rgb(33, 98, 161)" height="19" y="23" width="77" x="534" /><rect fill="rgb(35, 102, 165)" height="19" y="65" width="77" x="109" /><rect fill="rgb(5, 48, 97)" height="19" y="65" width="77" x="279" /><rect fill="rgb(129, 185, 216)" height="19" y="65" width="77" x="364" /><rect fill="rgb(21, 79, 138)" height="19" y="65" width="77" x="449" /><rect fill="rgb(8, 54, 106)" height="19" y="65" width="77" x="534" /><rect fill="rgb(160, 203, 226)" height="19" y="86" width="77" x="109" /><rect fill="rgb(129, 185, 216)" height="19" y="86" width="77" x="279" /><rect fill="rgb(5, 48, 97)" height="19" y="86" width="77" x="364" /><rect fill="rgb(118, 178, 212)" height="19" y="86" width="77" x="449" /><rect fill="rgb(160, 203, 226)" height="19" y="86" width="77" x="534" /><rect fill="rgb(51, 124, 182)" height="19" y="107" width="77" x="109" /><rect fill="rgb(21, 79, 138)" height="19" y="107" width="77" x="279" /><rect fill="rgb(118, 178, 212)" height="19" y="107" width="77" x="364" /><rect fill="rgb(5, 48, 97)" height="19" y="107" width="77" x="449" /><rect fill="rgb(21, 78, 138)" height="19" y="107" width="77" x="534" /><rect fill="rgb(33, 98, 161)" height="19" y="128" width="77" x="109" /><rect fill="rgb(8, 54, 106)" height="19" y="128" width="77" x="279" /><rect fill="rgb(160, 203, 226)" height="19" y="128" width="77" x="364" /><rect fill="rgb(21, 78, 138)" height="19" y="128" width="77" x="449" /><rect fill="rgb(5, 48, 97)" height="19" y="128" width="77" x="534" /></g><g transform="translate(38.5,9.5)" font-size="10" aria-label="text"><text fill="white" transform="translate(109,23)" y="0.32em">1.00</text><text fill="white" transform="translate(279,23)" y="0.32em">0.79</text><text fill="black" transform="translate(364 ...

// %%
let xvar = "organicCount";
let yvar = "gptReferenceCount";

Plot.plot({
    document,
    marks: [
        Plot.dot(allVis, {
            x: xvar,
            y: yvar,
            tip: true,
            fill: "currentColor",
        }),
        Plot.text(allVis, {
            x: xvar,
            y: yvar,
            text: "name",
            dy: -10,
            fontSize: 10,
        })
    ],
    x: { type: "band" },
    y: { grid: true },
    title: "Content Gap Analysis: Organic vs AI Overview Visibility",
    style: { backgroundColor: "white" },
});
// Out:
// <figure style="max-width:initial" class="plot-d6a7b5-figure"><h2>Content Gap Analysis: Organic vs AI Overview Visibility</h2><svg style="background-color:white" viewBox="0 0 640 400" height="400" width="640" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
//   --plot-background: white;
//   display: block;
//   height: auto;
//   height: intrinsic;
//   max-width: 100%;
// }
// :where(.plot-d6a7b5 text),
// :where(.plot-d6a7b5 tspan) {
//   white-space: pre;
// }</style><g stroke-opacity="0.1" stroke="currentColor" aria-hidden="true" aria-label="y-grid"><line y2="370" y1="370" x2="620" x1="40" /><line y2="331.1111111111111" y1="331.1111111111111" x2="620" x1="40" /><line y2="292.22222222222223" y1="292.22222222222223" x2="620" x1="40" /><line y2="253.33333333333334" y1="253.33333333333334" x2="620" x1="40" /><line y2="214.44444444444446" y1="214.44444444444446" x2="620" x1="40" /><line y2="175.55555555555554" y1="175.55555555555554" x2="620" x1="40" /><line y2="136.66666666666669" y1="136.66666666666669" x2="620" x1="40" /><line y2="97.77777777777777" y1="97.77777777777777" x2="620" x1="40" /><line y2="58.88888888888891" y1="58.88888888888891" x2="620" x1="40" /><line y2="20" y1="20" x2="620" x1="40" /></g><g stroke="currentColor" fill="none" aria-hidden="true" aria-label="y-axis tick"><path d="M0,0L-6,0" transform="translate(40,370)" /><path d="M0,0L-6,0" transform="translate(40,331.1111111111111)" /><path d="M0,0L-6,0" transform="translate(40,292.22222222222223)" /><path d="M0,0L-6,0" transform="translate(40,253.33333333333334)" /><path d="M0,0L-6,0" transform="translate(40,214.44444444444446)" /><path d="M0,0L-6,0" transform="translate(40,175.55555555555554)" /><path d="M0,0L-6,0" transform="translate(40,136.66666666666669)" /><path d="M0,0L-6,0" transform="translate(40,97.77777777777777)" /><path d="M0,0L-6,0" transform="translate(40,58.88888888888891)" /><path d="M0,0L-6,0" transform="translate(40,20)" /></g><g transform="translate(-9,0)" font-variant="tabular-nums" text-anchor="end" aria-label="y-axis tick label"><text transform="translate(40,370)" y="0.32em">0</text><text transform="translate(40,331.1111111111111)" y="0.32em">2</text><text transform="translate(40,292.22222222222223)" y="0.32em">4</text><text transform="translate(40,253.33333333333334)" y="0.32em">6</text><text transform="translate(40,214.44444444444446)" y="0.32em">8</text><text transform="translate(40,175.55555555555554)" y="0.32em">10</text><text transform="translate(40,136.66666666666669)" y="0.32em">12</text><text transform="translate(40,97.77777777777777)" y="0.32em">14</text><text transform="translate(40,58.88888888888891)" y="0.32em">16</text><text transform="translate(40,20)" y="0.32em">18</text></g><g transform="translate(-37,-17)" text-anchor="start" aria-label="y-axis label"><text transform="translate(40,20)" y="0.71em">↑ gptReferenceCount</text></g><g transform="translate(43,0)" stroke="currentColor" fill="none" aria-hidden="true" aria-label="x-axis tick"><path d="M0,0L0,6" transform="translate(50,370)" /><path d="M0,0L0,6" transform="translate(145,370)" /><path d="M0,0L0,6" transform="translate(240,370)" /><path d="M0,0L0,6" transform="translate(335,370)" /><path d="M0,0L0,6" transform="translate(430,370)" /><path d="M0,0L0,6" transform="translate(525,370)" /></g><g transform="translate(43,9)" aria-label="x-axis tick label"><text transform="translate(50,370)" y="0.71em">0</text><text transform="translate(145,370)" y="0.71em">1</text><text transform="translate(240,370)" y="0.71em">3</text><text transform="translate(335,370)" y="0.71em">7</text><text transform="translate(430,370)" y="0.71em">9</text><text transform="translate(525,370)" y="0.71em">18</text></g><g transform="translate(0,27)" aria-label="x-axis label"><text transform="translate(330,370)">organicCount</text></g><g transform="translate(43,0)" aria-label="dot"><circle r="3" cy="195" cx="525" /><circle r="3" cy="20" cx="430" /><circle r="3" cy="214.44444444444446" cx="335" /><circle r="3" cy="370" cx="240" /><circle r="3" cy="253.33333333333334" cx="145" /><circle r="3" cy="370" cx="50" /><circle r="3" cy="370" cx="50" /><circle r="3" cy="370" cx="50" /><circle r="3" cy="370" cx="50" /><circle r="3" cy="331.1111111111111" cx="50" /><circle r="3" cy="370" cx="50" /><circle r="3" cy="370" cx="50" /><circle r="3" cy="370" cx="50" /></g><g transform="translate(43,-10)" font-size="10" aria-label="text"><text transform="translate(525,195)" y="0. ...

// %% [markdown]
// # Branded visibility
//
// Do I rank at least, or can we find any relevant content when we include our brand in the topic queries?

// %%
// TODO

// %% [markdown]
// # Scrape content

// %%
let regenContent = false;

type ContentType = {
    urls: Record<string, Array<string>>;
    content: Record<string, scrape.ScrapeResponse>;
};

let content = await utils.fromCache(CACHE, 'competitorContent') as ContentType | null;
if (!content || regenContent) {
    console.log('Scraping SERP URL content...');
    let brandUrls = surfaceGap.extractBrandUrls(serps, brs);
    let flatUrls = Object.values(brandUrls).flat();
    let content = await scrape.scrapeWebBatch(
        flatUrls,
        {
            formats: ['text', 'markdown', 'html'],
            jsRendering: true,
        }
    );
    const urlToContent = Object.fromEntries(
        flatUrls.map((url, i) => [url, content[i]])
    );

    content = { urls: brandUrls, content: urlToContent };
    await utils.toCache(CACHE, content, 'overwrite', 'competitorContent');
} else {
    console.log('Loaded competitor content from cache');
}
// Out:
// Loaded competitor content from cache

// %%
let brandUrls = content.urls;
let urlContent = content.content;

// %%
brandUrls
// Out:
// {
//   Peugeot: [],
//   Toyota: [
//     "https://www.toyota.es/world-of-toyota/articles-news-events/como-desgravarse-compra-coche-electrico",
//     "https://www.toyota.es/calculadora-ayudas-coches-electricos",
//     "https://www.toyota.es/world-of-toyota/articles-news-events/plan-moves-iii-ayudas-comprar-electrico-hibrido-enchufable-toyota",
//     "https://www.toyota.es/world-of-toyota/articles-news-events/ayudas-plan-360-madrid",
//     "https://www.toyota.es/world-of-toyota/articles-news-events/beneficios-fiscales-flota-electrica-empresas",
//     "https://www.toyota.es/coches/vehiculos-etiqueta-cero",
//     "https://www.toyota.es/world-of-toyota/articles-news-events/ayudas-comprar-coche-electrico",
//     "https://www.toyota.es/promociones/electrico-bateria",
//     "https://www.toyota.es/promociones/toyota-bz4x-electric-4x2-advance-easy-plus"
//   ],
//   Tesla: [ "https://www.tesla.com/es_es/support/incentives" ],
//   BYD: [
//     "https://www.byd.com/es-es/promociones/seal-6-dmi-promocion",
//     "https://www.byd.com/es-es/promociones/preventa-atto-2"
//   ],
//   Hyundai: [],
//   Kia: [
//     "https://www.kia.com/es/todo-sobre-kia/territorio-kia/guias-y-ayuda/ayudas-compra-coche-electrico/",
//     "https://www.kia.com/es/plan-moves-kia/"
//   ],
//   Renault: [
//     "https://www.renault.es/blog/actualidad/ayudas-compra-coche-electrico.html",
//     "https://www.renault.es/blog/actualidad/ayudas-comprar-coche-ccaa.html",
//     "https://www.renault.es/blog/actualidad/plan-moves-guia-completa.html",
//     "https://www.renault.es/blog/trucos-consejos/desgravar-irpf-coche-electrico.html",
//     "https://www.renault.es/etiquetas-medio-ambiente/etiqueta-zero.html"
//   ],
//   Volkswagen: [
//     "https://www.volkswagen.es/es/quiero-un/volkswagen-con-moves3.html",
//     "https://www.volkswagen.es/es/electricos-hibridos/electricos/ofertas.html",
//     "https://www.volkswagen.es/es/modelos/id4.html"
//   ],
//   BMW: [
//     "https://www.bmw.es/es/topics/mundo-bmw/cultura-bmw/vehiculos-cero-eco.html"
//   ],
//   Audi: [ "https://www.audi.es/es/electromovilidad/plan-moves/" ],
//   Mercedes: [],
//   Honda: [],
//   MG: []
// }

// %% [markdown]
// # Analyze content

// %%
let currBrand = 'Peugeot';
let currBrandUrls = brandUrls[currBrand]
currBrandUrls
// Out:
// []

// %% [markdown]
// # Content format analysis

// %%
import * as parse from "../../src/analysis/parseHtml.ts?v=203";

// %%
let currUrl = currBrandUrls[0];
console.log(`Analyzing content from URL: ${currUrl}`);
let currContent = urlContent[currUrl]?.content || "";
let $ = parse.html(currContent, currUrl);
// Out:
// Analyzing content from URL: undefined

// %%
// Manual URL for testing
let currUrl = "https://www.peugeot.es/electricos-e-hibridos/certificados-ahorro-energetico.html"
let scraped = await scrape.scrapeWeb(
    currUrl,
    {
        formats: ['text', 'markdown', 'html'],
        jsRendering: true,
    }
);
let currContent = scraped.content;
let $ = parse.html(currContent, currUrl);

// %% [markdown]
// ## Structured Data: Json-LD for Google rich results

// %%
let structData = parse.structuredData($);

$ = parse.main($);
void 0;

// %%
for (const item of structData) {
    console.log(JSON.stringify(item, null, 2));
}

// %%
let includedSchemas = parse.checkStructuredDataTypes(structData);
includedSchemas
// Out:
// {
//   Article: false,
//   Author: false,
//   BlogPosting: false,
//   BreadcrumbList: false,
//   Event: false,
//   FAQPage: false,
//   HowTo: false,
//   JobPosting: false,
//   LocalBusiness: false,
//   Organization: false,
//   Person: false,
//   Product: false,
//   Recipe: false,
//   Review: false,
//   Service: false,
//   SoftwareApplication: false,
//   VideoObject: false,
//   WebSite: false
// }

// %% [markdown]
// ## Headings

// %%
let headings = parse.headings($);
for (let h of headings) {
    console.log(`${h.tag}: ${h.text}`);
}
// Out:
// h1: CAE: 1.000€ POR PASARTE AL ELÉCTRICO
// h2: AHORRA 1.000€ POR CAMBIAR TU COCHE DE COMBUSTIÓN
// POR UN PEUGEOT 100% ELÉCTRICO
// h3: ¿Qué son los CAEs?
// h3: ¿Qué modelos de Peugeot están incluidos?
// h6: E-TRAVELLER
// h6: E-PARTNER
// h6: E-EXPERT
// h6: E-BOXER
// h6: E-208
// h6: E-2008
// h6: NUEVO E-308
// h6: NUEVO E-308 SW
// h6: E-3008
// h6: E-408
// h6: E-5008
// h6: E-RIFTER
// h6: E-TRAVELLER
// h6: E-PARTNER
// h6: E-EXPERT
// h6: E-BOXER
// h6: E-208
// h6: E-2008
// h6: NUEVO E-308
// h6: NUEVO E-308 SW
// h6: E-3008
// h6: E-408
// h6: E-5008
// h6: E-RIFTER
// h6: E-TRAVELLER
// h6: E-PARTNER
// h6: E-EXPERT
// h6: E-BOXER
// h3: ¿Cuánto puedes recibir?
// h3: ¿Cómo beneficiarte del CAE con PEUGEOT?
//
// Los CAE, paso a paso
// h3: COMPATIBILIDAD CON OTRAS AYUDAS
// h3: Beneficios de la bonificación CAE
// h3: FAQ: PREGUNTAS Y RESPUESTAS
// h3: ¿Cuánto puedes ahorrar?
// h3: ¿Cómo beneficiarte del CAE con Peugeot?
// h3: ¿Cuál es la documentación necesaria para poder aplicar la bonificación CAE con Peugeot?
// h3: ¿Que son los beneficios de las bonificaciones CAE?
// h3: ¿Dónde puedo encontrar más detalles sobre los Certificados de Ahorro Energetico (CAEs)?
// h3: Plan MOVES III 2025
// h3: Deducción IRPF hasta 3000€
// h3: ¿Tienes más preguntas?

// %% [markdown]
// ## Paragraphs

// %%
let paragraphs = parse.paragraphs($);
console.log(`Total paragraphs: ${paragraphs.length}`);
console.log('Sample paragraphs:');
for (let p of paragraphs.slice(0, 5)) {
    console.log(`- ${p.slice(0, 100)}...`);
}
// Out:
// Total paragraphs: 171
// Sample paragraphs:
// - Peugeot se suma al nuevo sistema de Certificados de Ahorro Energético (CAE), una iniciativa respalda...
// - Recibe una bonificación de 1.000 € (IVA incluido) por cambiar tu coche de combustión por un vehículo...
// - Los Certificados de Ahorro Energético (CAE) son un mecanismo nacional que reconoce y recompensa los ...
// - Cuando eliges un Peugeot eléctrico, estás contribuyendo a una movilidad más limpia y eso tiene recom...
// - Con el programa CAE, recibirás una bonificación económica directa de 1000€, gestionada íntegramente ...

// %% [markdown]
// ## Lists

// %%
let lists = parse.lists($);
console.log(`Total lists: ${lists.length}`);
console.log('Sample lists:');
for (let l of lists.slice(0, 5)) {
    console.log(`\n- List with ${l.items.length} items: ${l.contextHeading}, URL: ${l.contextLink}`);
    for (let item of l.items.slice(0, 5)) {
        console.log(`  - ${item.slice(0, 100)}...`);
    }
}
// Out:
// Total lists: 5
// Sample lists:
//
// - List with 12 items: E-BOXER, URL: undefined
//   - Go to slide 1...
//   - Go to slide 2...
//   - Go to slide 3...
//   - Go to slide 4...
//   - Go to slide 5...
//
// - List with 4 items: ¿Cómo beneficiarte del CAE con Peugeot?, URL: undefined
//   - Acude a tu concesionario Peugeot más cercano...
//   - Elige tu vehículo eléctrico...
//   - El concesionario gestionará el expediente CAE...
//   - Esta bonificación se entrega mediante una factura independiente, gestionada por el concesionario....
//
// - List with 1 items: ¿Que son los beneficios de las bonificaciones CAE?, URL: undefined
//   - Reducen el coste de adquisición:...
//
// - List with 1 items: ¿Que son los beneficios de las bonificaciones CAE?, URL: undefined
//   - Incentivan la transición a la movilidad eléctrica:...
//
// - List with 1 items: ¿Que son los beneficios de las bonificaciones CAE?, URL: undefined
//   - Contribuyen a la reducción del consumo de energía:...

// %% [markdown]
// ## Tables

// %%
let tables = parse.tables($);
console.log(`Total tables: ${tables.length}`);
tables[0]
// Out:
// Total tables: 0

// %% [markdown]
// ## Links

// %%
let links = parse.links($, true);
let linksDf = pl.DataFrame(links).sort("isExternal", true);
linksDf
// Out:
// <table><thead><tr><th>text</th><th>href</th><th>isExternal</th><th>isPdf</th></tr></thead><tbody><tr><td>página web</td><td>https://www.miteco.gob.es/es/energia/eficiencia/cae.html</td><td>true</td><td>false</td></tr><tr><td>Información MOVES III 2025</td><td>https://www.idae.es/ayudas-y-financiacion/para-movilidad-y-vehiculos/moves-iii-2025</td><td>true</td><td>false</td></tr><tr><td>Convocatorias de las Comunidades Autónomas</td><td>https://www.idae.es/ayudas-y-financiacion/para-movilidad-y-vehiculos/moves-iii-2025/convocatorias-de-las-comunidades-autonomas</td><td>true</td><td>false</td></tr><tr><td>Guía para acceder a las ayudas</td><td>https://www.idae.es/sites/default/files/documentos/ayudas_y_financiacion/MOVES_III/MOVES_III_GUIA_CIUDADANOS_VEHICULOS_28022025.pdf</td><td>true</td><td>true</td></tr><tr><td>Agencia Tributaria: Deducción IRPF por la adquisición de vehículos eléctricos</td><td>https://sede.agenciatributaria.gob.es/Sede/vehiculos-embarcaciones/deduccion-irpf-adquisicion-vehiculos-electricos/deduccion-adquisicion-vehiculos-electricos-enchufables.html</td><td>true</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/traveller-standard?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/208-5-puertas?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/2008-suv?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/nuevo-308-5-puertas?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/nuevo-308-sw?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/3008-suv?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/408-berlina?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/5008-suv?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr><tr><td>CONFIGURA Y COMPRA</td><td>https://store.peugeot.es/trim/configurable/rifter-standard?fuel=El%C3%A9ctrico</td><td>false</td><td>false</td></tr></tbody></table>

// %% [markdown]
// ## Questions

// %%
let body = parse.bodyText($);
console.log(body.slice(0, 500));
// Out:
// CAE: 1.000€ POR PASARTE AL ELÉCTRICO CAE: 1.000€ POR PASARTE AL ELÉCTRICO AHORRA 1.000€ POR CAMBIAR TU COCHE DE COMBUSTIÓN POR UN PEUGEOT 100% ELÉCTRICO Peugeot se suma al nuevo sistema de Certificados de Ahorro Energético (CAE), una iniciativa respaldada por el Ministerio para la Transición Ecológica. Recibe una bonificación de 1.000 € (IVA incluido) por cambiar tu coche de combustión por un vehículo 100% eléctrico PEUGEOT. AHORRA 1.000€ POR CAMBIAR TU COCHE DE COMBUSTIÓN POR UN PEUGEOT 100% EL

// %%
let questions = body.match(/[^.!?]*\?/g) || [];
console.log(`Found ${questions.length} questions`);
for (let q of questions.slice(0, 10)) {
    console.log(`- ${q.trim()}`);
}
// Out:
// Found 11 questions
// - ¿Qué son los CAEs?
// - ¿Qué modelos de Peugeot están incluidos?
// - 000 km en RENTING TODO INCLUIDO 900 € de ayuda en contratos ≥24 meses (CAES) Connect Fleet incluido Punto de carga easyWallbox incluido** Emisiones, Consumos y Condiciones Legales CONFIGURADOR PIDE UNA OFERTA Go to slide 1 Go to slide 2 Go to slide 3 Go to slide 4 Go to slide 5 Go to slide 6 Go to slide 7 Go to slide 8 Go to slide 9 Go to slide 10 Go to slide 11 Go to slide 12 ¿Cuánto puedes recibir?
// - ¿Cómo beneficiarte del CAE con PEUGEOT?
// - FAQ: PREGUNTAS Y RESPUESTAS ¿Cuánto puedes ahorrar?
// - ¿Cómo beneficiarte del CAE con Peugeot?
// - ¿Cuál es la documentación necesaria para poder aplicar la bonificación CAE con Peugeot?
// - Declaración de responsabilidad ¿Que son los beneficios de las bonificaciones CAE?
// - ¿Dónde puedo encontrar más detalles sobre los Certificados de Ahorro Energetico (CAEs)?
// - ¿Se puede deducir también la instalación de un punto de carga?

// %% [markdown]
// # Forms

// %%
import * as parse from "../../src/analysis/parseHtml.ts?v=206";

let forms = parse.forms($);
console.log(`Total forms: ${forms.length}`);
// Out:
// Total forms: 0

// %%
forms[0];

// %% [markdown]
// ## Structured content result

// %%
type StructuredContent = {
    schemas: Array<Record<string, unknown>>;
    headings: Array<{ tag: string; text: string }>;
    paragraphs: Array<string>;
    lists: Array<{ contextHeading: string; items: Array<string> }>;
    tables: Array<{ contextHeading: string; headers: Array<string>; rows: Array<Array<string>> }>;
    links: Array<{ href: string; text: string; isExternal: boolean }>;
    forms: Array<parse.Form>;
}

let structuredContent: StructuredContent = {
    schemas: structData,
    headings: headings,
    paragraphs: paragraphs,
    lists: lists,
    tables: tables,
    links: links,
    forms: forms
};

structuredContent
// Out:
// {
//   schemas: [],
//   headings: [
//     { tag: "h1", text: "CAE: 1.000€ POR PASARTE AL ELÉCTRICO" },
//     {
//       tag: "h2",
//       text: "AHORRA 1.000€ POR CAMBIAR TU COCHE DE COMBUSTIÓN\n" +
//         "POR UN PEUGEOT 100% ELÉCTRICO"
//     },
//     { tag: "h3", text: "¿Qué son los CAEs?" },
//     { tag: "h3", text: "¿Qué modelos de Peugeot están incluidos?" },
//     { tag: "h6", text: "E-TRAVELLER" },
//     { tag: "h6", text: "E-PARTNER" },
//     { tag: "h6", text: "E-EXPERT" },
//     { tag: "h6", text: "E-BOXER" },
//     { tag: "h6", text: "E-208" },
//     { tag: "h6", text: "E-2008" },
//     { tag: "h6", text: "NUEVO E-308" },
//     { tag: "h6", text: "NUEVO E-308 SW" },
//     { tag: "h6", text: "E-3008" },
//     { tag: "h6", text: "E-408" },
//     { tag: "h6", text: "E-5008" },
//     { tag: "h6", text: "E-RIFTER" },
//     { tag: "h6", text: "E-TRAVELLER" },
//     { tag: "h6", text: "E-PARTNER" },
//     { tag: "h6", text: "E-EXPERT" },
//     { tag: "h6", text: "E-BOXER" },
//     { tag: "h6", text: "E-208" },
//     { tag: "h6", text: "E-2008" },
//     { tag: "h6", text: "NUEVO E-308" },
//     { tag: "h6", text: "NUEVO E-308 SW" },
//     { tag: "h6", text: "E-3008" },
//     { tag: "h6", text: "E-408" },
//     { tag: "h6", text: "E-5008" },
//     { tag: "h6", text: "E-RIFTER" },
//     { tag: "h6", text: "E-TRAVELLER" },
//     { tag: "h6", text: "E-PARTNER" },
//     { tag: "h6", text: "E-EXPERT" },
//     { tag: "h6", text: "E-BOXER" },
//     { tag: "h3", text: "¿Cuánto puedes recibir?" },
//     {
//       tag: "h3",
//       text: "¿Cómo beneficiarte del CAE con PEUGEOT?\n \nLos CAE, paso a paso"
//     },
//     { tag: "h3", text: "COMPATIBILIDAD CON OTRAS AYUDAS" },
//     { tag: "h3", text: "Beneficios de la bonificación CAE" },
//     { tag: "h3", text: "FAQ: PREGUNTAS Y RESPUESTAS" },
//     { tag: "h3", text: "¿Cuánto puedes ahorrar?" },
//     { tag: "h3", text: "¿Cómo beneficiarte del CAE con Peugeot?" },
//     {
//       tag: "h3",
//       text: "¿Cuál es la documentación necesaria para poder aplicar la bonificación CAE con Peugeot?"
//     },
//     {
//       tag: "h3",
//       text: "¿Que son los beneficios de las bonificaciones CAE?"
//     },
//     {
//       tag: "h3",
//       text: "¿Dónde puedo encontrar más detalles sobre los Certificados de Ahorro Energetico (CAEs)?"
//     },
//     { tag: "h3", text: "Plan MOVES III 2025" },
//     { tag: "h3", text: "Deducción IRPF hasta 3000€" },
//     { tag: "h3", text: "¿Tienes más preguntas?" }
//   ],
//   paragraphs: [
//     "Peugeot se suma al nuevo sistema de Certificados de Ahorro Energético (CAE), una iniciativa respaldada por el Ministerio para la Transición Ecológica.",
//     "Recibe una bonificación de 1.000 € (IVA incluido) por cambiar tu coche de combustión por un vehículo 100% eléctrico PEUGEOT.",
//     "Los Certificados de Ahorro Energético (CAE) son un mecanismo nacional que reconoce y recompensa los proyectos que generan ahorro energético.",
//     "Cuando eliges un Peugeot eléctrico, estás contribuyendo a una movilidad más limpia y eso tiene recompensa.",
//     "Con el programa CAE, recibirás una bonificación económica directa de 1000€, gestionada íntegramente a través de nuestra red de concesionarios.",
//     "Esta bonificación no reduce el precio de tu vehículo.",
//     "Los CAEs no se consideran una subvención, sino una monetización derivada de la venta de los ahorros energéticos certificados, tras la cesión de un vehículo de combustión del cual hayas sido titular durante al menos 12 meses, para la adquisición de un vehículo 100 % eléctrico.",
//     "La bonificación CAE se aplica a toda la gama 100 % eléctrica de Peugeot (turismos, SUVs y vehículos comerciales eléctricos).",
//     "Aplica tanto a clientes particulares como profesionales (autónomos, pymes y flotas). El renting para empresas está disponible con Leasys.",
//     "Con seguro de crédito\nDesde 465€/mes(12d)",
//     "Última cuota: 22.650,50€",
//     "Por 455€/mes(13d) + IVA",
//     "en RENTING TODO INCLUIDO",
//     "900 € de ayuda en contratos ≥24 meses (CAES)",
//     "Connect Fleet incluido",
//     "Punto de carga easyWallbox incluido**",
//     "Por 549€/mes(14d) + IVA",
//     "en RENTING TODO INCLUIDO",
//     "900 € de ayuda en contratos ≥24 meses (CAES)",
//     "Connect Fleet incluido",
//     "Punto de carga easyWallbox incluido**",
//     "Por 726€/mes(15d) + IVA",
//     "en RENTING TODO INCLUIDO",
//     "900 € de ayuda en contratos ≥24 meses (CAES)",
//     "Connect Fleet incluido",
//     "Punto de carga easyWallbox incluido**",
//     "Con seguro de crédito\nDesde 150€/mes(1d)",
//     "Última cuota: 15.827,15€",
//     "Renting todo incluido",
//     "Primera cuota: 2.028,68€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 180€/mes(2d)",
//     "Última cuota: 18.336,78€",
//     "Renting todo incluido",
//     "Primera cuota: 2.855,38€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 250€/mes(3d)",
//     "Última cuota: 19.210€",
//     "Renting todo incluido",
//     "Primera cuota: 3.335,91€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 260€/mes(4d)",
//     "Última cuota: 19.266,80€",
//     "Renting todo incluido",
//     "Primera cuota: 3.335,91€",
//     "Plan MOVES III incluido",
//     "Con mantenimiento\nDesde 290€/mes(5d)",
//     "Última cuota: 23.960,82€",
//     "Renting todo incluido",
//     "Primera cuota: 3.698,66€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 270€/mes(6d)",
//     "Última cuota: 22.921,50€",
//     "Renting todo incluido",
//     "Primera cuota: 6.506,61€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 300€/mes(9d)",
//     "Última cuota: 28.670,85€",
//     "Renting todo incluido",
//     "Primera cuota: 3.732,26€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 325€/mes(11d)",
//     "Última cuota: 18.629,30€",
//     "Con seguro de crédito\nDesde 465€/mes(12d)",
//     "Última cuota: 22.650,50€",
//     "Por 455€/mes(13d) + IVA",
//     "en RENTING TODO INCLUIDO",
//     "900 € de ayuda en contratos ≥24 meses (CAES)",
//     "Connect Fleet incluido",
//     "Punto de carga easyWallbox incluido**",
//     "Por 549€/mes(14d) + IVA",
//     "en RENTING TODO INCLUIDO",
//     "900 € de ayuda en contratos ≥24 meses (CAES)",
//     "Connect Fleet incluido",
//     "Punto de carga easyWallbox incluido**",
//     "Por 726€/mes(15d) + IVA",
//     "en RENTING TODO INCLUIDO",
//     "900 € de ayuda en contratos ≥24 meses (CAES)",
//     "Connect Fleet incluido",
//     "Punto de carga easyWallbox incluido**",
//     "Con seguro de crédito\nDesde 150€/mes(1d)",
//     "Última cuota: 15.827,15€",
//     "Renting todo incluido",
//     "Primera cuota: 2.028,68€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 180€/mes(2d)",
//     "Última cuota: 18.336,78€",
//     "Renting todo incluido",
//     "Primera cuota: 2.855,38€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 250€/mes(3d)",
//     "Última cuota: 19.210€",
//     "Renting todo incluido",
//     "Primera cuota: 3.335,91€",
//     "Plan MOVES III incluido",
//     "Con seguro de crédito\nDesde 260€/mes(4d)",
//     "Última cuota: 19.266,80€",
//     "Renting todo incluido",
//     "Primera cuota: 3.335,91€",
//     "Plan MOVES III incluido",
//     ... 71 more items
//   ],
//   lists: [
//     {
//       ordered: false,
//       items: [
//         "Go to slide 1",
//         "Go to slide 2",
//         "Go to slide 3",
//         "Go to slide 4",
//         "Go to slide 5",
//         "Go to slide 6",
//         "Go to slide 7",
//         "Go to slide 8",
//         "Go to slide 9",
//         "Go to slide 10",
//         "Go to slide 11",
//         "Go to slide 12"
//       ],
//       contextHeading: "E-BOXER"
//     },
//     {
//       ordered: true,
//       items: [
//         "Acude a tu concesionario Peugeot más cercano",
//         "Elige tu vehículo eléctrico",
//         "El concesionario gestionará el expediente CAE",
//         "Esta bonificación se entrega mediante una factura independiente, gestionada por el concesionario."
//       ],
//       contextHeading: "¿Cómo beneficiarte del CAE con Peugeot?"
//     },
//     {
//       ordered: false,
//       items: [ "Reducen el coste de adquisición:" ],
//       contextHeading: "¿Que son los beneficios de las bonificaciones CAE?"
//     },
//     {
//       ordered: false,
//       items: [ "Incentivan la transición a la movilidad eléctrica:" ],
//       contextHeading: "¿Que son los beneficios de las bonificaciones CAE?"
//     },
//     {
//       ordered: false,
//       items: [ "Contribuyen a la reducción del consumo de energía:" ],
//       contextHeading: "¿Que son los beneficios de las bonificaciones CAE?"
//     }
//   ],
//   tables: [],
//   links: [
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/traveller-standard?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/208-5-puertas?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/2008-suv?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/nuevo-308-5-puertas?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/nuevo-308-sw?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/3008-suv?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/408-berlina?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/5008-suv?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "CONFIGURA Y COMPRA",
//       href: "https://store.peugeot.es/trim/configurable/rifter-standard?fuel=El%C3%A9ctrico",
//       isExternal: false,
//       isPdf: false
//     },
//     {
//       text: "página web",
//       href: "https://www.miteco.gob.es/es/energia/eficiencia/cae.html",
//       isExternal: true,
//       isPdf: false
//     },
//     {
//       text: "Información MOVES III 2025",
//       href: "https://www.idae.es/ayudas-y-financiacion/para-movilidad-y-vehiculos/moves-iii-2025",
//       isExternal: true,
//       isPdf: false
//     },
//     {
//       text: "Convocatorias de las Comunidades Autónomas",
//       href: "https://www.idae.es/ayudas-y-financiacion/para-movilidad-y-vehiculos/moves-iii-2025/convocatorias-de-las-comunidades-autonomas",
//       isExternal: true,
//       isPdf: false
//     },
//     {
//       text: "Guía para acceder a las ayudas",
//       href: "https://www.idae.es/sites/default/files/documentos/ayudas_y_financiacion/MOVES_III/MOVES_III_GUIA_CIUDADANOS_VEHICULOS_28022025.pdf",
//       isExternal: true,
//       isPdf: true
//     },
//     {
//       text: "Agencia Tributaria: Deducción IRPF por la adquisición de vehículos eléctricos",
//       href: "https://sede.agenciatributaria.gob.es/Sede/vehiculos-embarcaciones/deduccion-irpf-adquisicion-vehiculos-electricos/deduccion-adquisicion-vehiculos-electricos-enchufables.html",
//       isExternal: true,
//       isPdf: false
//     }
//   ],
//   forms: []
// }

// %% [markdown]
// ## Content categories
//
// - Article, Blog Post, Listicle, Comparison (table), Calculator, Product page, Hub, How-to, News

// %%
let ContentTypeSchema = z.object({
    type: z.enum([
        "Article",
        "Blog Post",
        "Listicle",
        "Comparison",
        "Calculator",
        "Product Page",
        "Hub",
        "How-to",
        "News"
    ]).describe("Category best describing the web page. Select the most specific if applicable (e.g. Listicle, Product Page), otherwise more general (e.g. Article)."),
    reason: z.string().describe("Brief explanation (single phrase) of why this content type was assigned."),
}).describe("Categorization of the web page.");

let ContentElementSchema = z.object({
    elementType: z.enum([
        "List",
        "Listicle",
        "Comparison",
        "Calculator"
    ]).describe("Type of content element found on the page. Although a page may not be categorized specifically as a Listicle or Comparison, it may still contain such elements."),
    contextHeading: z.string().describe("The heading or section title under which this content element is found."),
}).describe("Specific content elements identified within the web page that contribute to its overall categorization.");

let StructuredContentSchema = z.object({
    types: z.array(ContentTypeSchema).describe("One or more content types. A web page can be both a general type (e.g. Article) and a more specific type (e.g. Listicle). If multiple types are assigned, they should be listed from most specific to most general. Do NOT include types that are not applicable."),
    elements: z.array(ContentElementSchema).describe("List of specific content elements identified on the page that support its categorization."),
}).describe("Structured representation of the web page's content type and its constituent elements based on HTML analysis.");

// %%
// ------ HTML based ------
let catPromptHTML = `
Analyze the following web page HTML content and check whether it belongs to one or more of the following categories:
Article, Blog Post, Listicle, Comparison, Calculator, Product page, Hub, How-to, News. Also check whether any of the following
content elements are present: List, Listicle, Comparison, Calculator. In the output provide the list of applicable categories
(with reason) and the list of detected content blocks (with heading and direct url if available).
To classify the overall page category (e.g. Article, Blog Post, Listicle etc.) focus on the content of the headings (h1, h2).
For Listicles and Comparisons, focus on the presence and content of lists or tables.
For product pages, focus on the presence of product information in the structured data, e.g. lists of products or offers,
or headings that suggest product listings. To detect a hub, focus on the quantity of internal links to related articles or sections.

## Base URI
${currUrl}

## HTML Content
{content}
`
    .replace("{content}", $.html())
    .trim();

let result = await askOpenAISafe(
    catPromptHTML,
    'gpt-5.1',
    StructuredContentSchema,
    { reasoning: { effort: 'low' } }
);

if (result.parsed) {
    console.log(result.parsed);
}
// Out:
// {
//   types: [
//     {
//       type: "Product Page",
//       reason: "Landing page promoting Peugeot’s 100% electric range with many model tiles, finance offers, configurator CTAs and “Pide una oferta” links, centered around the CAE bonus (h1 and h2 are promotional, not editorial)."
//     },
//     {
//       type: "How-to",
//       reason: "Contains clear procedural sections like “¿Cómo beneficiarte del CAE con PEUGEOT? Los CAE, paso a paso” with numbered steps explaining what to do."
//     }
//   ],
//   elements: [
//     {
//       elementType: "List",
//       contextHeading: "¿Cómo beneficiarte del CAE con PEUGEOT? / Los CAE, paso a paso"
//     },
//     {
//       elementType: "List",
//       contextHeading: "Beneficios de la bonificación CAE"
//     },
//     {
//       elementType: "List",
//       contextHeading: "¿Cómo beneficiarte del CAE con Peugeot?"
//     },
//     {
//       elementType: "List",
//       contextHeading: "¿Cuál es la documentación necesaria para poder aplicar la bonificación CAE con Peugeot?"
//     },
//     {
//       elementType: "List",
//       contextHeading: "¿Que son los beneficios de las bonificaciones CAE?"
//     },
//     { elementType: "List", contextHeading: "Plan MOVES III 2025" },
//     {
//       elementType: "List",
//       contextHeading: "Deducción IRPF hasta 3000€"
//     }
//   ]
// }

// %%
// ------ Structure based ------
let catPromptStruct = `
Analyze the following structured web page content and check whether it belongs to one or more of the following categories:
Article, Blog Post, Listicle, Comparison, Calculator, Product page, Hub, How-to, News. Also check whether any of the following
content elements are present: List, Listicle, Comparison, Calculator. In the output provide the list of applicable categories
(with reason) and the list of detected content blocks (with heading and direct url if available).
To classify the overall page category (e.g. Article, Blog Post, Listicle etc.) focus on the schemas and the content of the headings (h1, h2).
For Listicles and Comparisons, focus on the presence and content of lists or tables.
For product pages, focus on the presence of product information in the structured data, e.g. lists of products or offers,
or headings that suggest product listings.
To detect a hub, focus on the quantity of internal links to related articles or sections.

## Base URI
${currUrl}

## HTML Content
{content}
`
    .replace("{content}", JSON.stringify(structuredContent, null, 2))
    .trim();

let result = await askOpenAISafe(
    catPromptStruct,
    'gpt-5.1',
    StructuredContentSchema,
    { reasoning: { effort: 'low' } }
);

if (result.parsed) {
    console.log(result.parsed);
}
// Out:
// {
//   types: [
//     {
//       type: "How-to",
//       reason: "The page explains how to obtain and benefit from the CAE (Certificados de Ahorro Energético) with step-by-step instructions under headings like “¿Cómo beneficiarte del CAE con Peugeot?” and related procedural FAQs."
//     },
//     {
//       type: "Article",
//       reason: "Provides general informational content about energy-saving certificates, compatible models, fiscal deductions, and related aids, structured with explanatory H2/H3 sections and FAQs rather than being primarily commercial product detail."
//     }
//   ],
//   elements: [
//     { elementType: "List", contextHeading: "E-BOXER" },
//     {
//       elementType: "List",
//       contextHeading: "¿Cómo beneficiarte del CAE con Peugeot?"
//     },
//     {
//       elementType: "List",
//       contextHeading: "¿Que son los beneficios de las bonificaciones CAE?"
//     },
//     {
//       elementType: "List",
//       contextHeading: "¿Que son los beneficios de las bonificaciones CAE?"
//     },
//     {
//       elementType: "List",
//       contextHeading: "¿Que son los beneficios de las bonificaciones CAE?"
//     }
//   ]
// }

// %% [markdown]
// ## Content element categories

// %%
import * as parse from "../../src/analysis/parseHtml.ts?v=207";

let classifiedLists = await parse.classifyElements(lists, 'list');
let classifiedTables = await parse.classifyElements(tables, 'table');
let classifiedForms = await parse.classifyElements(forms, 'form');

console.log(`Classified ${classifiedLists.length} lists, ${classifiedTables.length} tables, ${classifiedForms.length} forms`);
// Out:
// Classified 5 lists, 0 tables, 0 forms

// %%
classifiedLists
// Out:
// [
//   {
//     ordered: false,
//     items: [
//       "Go to slide 1",
//       "Go to slide 2",
//       "Go to slide 3",
//       "Go to slide 4",
//       "Go to slide 5",
//       "Go to slide 6",
//       "Go to slide 7",
//       "Go to slide 8",
//       "Go to slide 9",
//       "Go to slide 10",
//       "Go to slide 11",
//       "Go to slide 12"
//     ],
//     contextHeading: "E-BOXER",
//     classification: {
//       type: "Navigation",
//       confidence: "high",
//       reason: "The list items serve as navigation links directing to specific slides."
//     }
//   },
//   {
//     ordered: true,
//     items: [
//       "Acude a tu concesionario Peugeot más cercano",
//       "Elige tu vehículo eléctrico",
//       "El concesionario gestionará el expediente CAE",
//       "Esta bonificación se entrega mediante una factura independiente, gestionada por el concesionario."
//     ],
//     contextHeading: "¿Cómo beneficiarte del CAE con Peugeot?",
//     classification: {
//       type: "Steps",
//       confidence: "high",
//       reason: "The ordered list provides a sequential process to benefit from the CAE with Peugeot, indicating step-by-step instructions."
//     }
//   },
//   {
//     ordered: false,
//     items: [ "Reducen el coste de adquisición:" ],
//     contextHeading: "¿Que son los beneficios de las bonificaciones CAE?",
//     classification: {
//       type: "Benefits",
//       confidence: "high",
//       reason: "The item explicitly mentions 'Reducen el coste de adquisición,' indicating it describes a benefit of the CAE bonuses."
//     }
//   },
//   {
//     ordered: false,
//     items: [ "Incentivan la transición a la movilidad eléctrica:" ],
//     contextHeading: "¿Que son los beneficios de las bonificaciones CAE?",
//     classification: {
//       type: "Benefits",
//       confidence: "high",
//       reason: "The list item describes an advantage related to CAE bonuses, indicating benefits provided."
//     }
//   },
//   {
//     ordered: false,
//     items: [ "Contribuyen a la reducción del consumo de energía:" ],
//     contextHeading: "¿Que son los beneficios de las bonificaciones CAE?",
//     classification: {
//       type: "Benefits",
//       confidence: "high",
//       reason: "The item describes a positive effect (energy consumption reduction) related to the benefits mentioned in the heading."
//     }
//   }
// ]

// %% [markdown]
// ## Entities
// Which entities are mentioned in well-ranking pages?

// %%
import * as entities from "../../src/entities.ts?v=6";

let instructions = `
Extract any relevant entities or keywords from the text related to electric vehicles and government subsidies.
These will be used to brief content creation, so focus on terms that would help in writing informative articles
similar to the input text but for a different brand.
`.trim();

let bodyEnts = await entities.extractAnyEntities(body, instructions, 'gpt-5.1', { reasoning: { effort: 'none' } });

// %%
for (const type of [...new Set(bodyEnts.map(e => e.type))]) {
    const entities = bodyEnts.filter(e => e.type === type).map(e => e.name);
    console.log(`\n**${type}**\n`);
    for (const entity of entities) {
        console.log(`- ${entity}`);
    }
}
// Out:
// **brand**
//
// - peugeot
//
// **product**
//
// - vehículo eléctrico
// - coche eléctrico
// - e-traveller
// - e-partner
// - e-expert
// - e-boxer
// - e-208
// - e-2008
// - e-3008
// - e-308
// - e-308 sw
// - e-408
// - e-5008
// - e-rifter
//
// **product line**
//
// - gama 100 % eléctrica de peugeot
//
// **product subtype**
//
// - turismo eléctrico
// - suv eléctrico
// - vehículo comercial eléctrico
//
// **product (reference/old technology)**
//
// - coche de combustión
// - vehículo de combustión
//
// **concept**
//
// - movilidad eléctrica
// - electrificación de la movilidad
// - ahorro energético
//
// **policy instrument**
//
// - certificado de ahorro energético
// - cae
// - certificados de ahorro energético
//
// **subsidy program**
//
// - programa cae
// - plan moves iii
// - programa moves iii 2025
// - programa de incentivos ligados a la movilidad eléctrica
//
// **financial incentive**
//
// - bonificación cae
// - bonificación económica directa
// - bonificación de 1.000 €
// - ayuda de 900 €
// - ayuda gubernamental
// - subvención
//
// **tax incentive**
//
// - deducción irpf
// - deducción del 15% en el irpf
// - deducción irpf hasta 3000€
// - deducción por la adquisición de vehículos eléctricos
// - deducción por la instalación de puntos de recarga
//
// **regional incentive**
//
// - ayudas de las comunidades autónomas
//
// **government body**
//
// - ministerio para la transición ecológica
// - ministerio para la transición ecológica y el reto demográfico
// - miteco
// - consejo de ministros
// - agencia tributaria
//
// **regional government**
//
// - comunidad autónoma
//
// **company (program operator)**
//
// - murartech
//
// **company (leasing provider)**
//
// - leasys
//
// **distribution channel**
//
// - red de concesionarios
// - concesionario peugeot
//
// **financing model**
//
// - renting
// - leasing
// - renting para empresas
//
// **financing feature**
//
// - renting todo incluido
//
// **financial product**
//
// - seguro de crédito
//
// **service (fleet management)**
//
// - connect fleet
//
// **charging hardware**
//
// - easywallbox
// - punto de carga easywallbox
//
// **charging infrastructure**
//
// - infraestructura de recarga
// - punto de recarga
// - punto de carga
//
// **environmental benefit**
//
// - movilidad más limpia
// - reducción de emisiones
// - reducción del consumo de energía
//
// **environmental concept**
//
// - gases de efecto invernadero
//
// **mechanism**
//
// - venta de los ahorros energéticos certificados
//
// **eligibility condition**
//
// - cesión de un vehículo de combustión
//
// **economic concept**
//
// - coste de adquisición
//
// **tax**
//
// - impuesto sobre la renta de las personas físicas
// - irpf
// - impuesto de transmisiones patrimoniales
// - ivtm
//
// **legal instrument**
//
// - real decreto-ley
//
// **administrative mechanism**
//
// - factura independiente
//
// **administrative document**
//
// - documento de cambio de titularidad
// - informe dgt
// - ficha técnica
// - acuerdo de cesión de ahorro
// - declaración de responsabilidad
//
// **purchase category**
//
// - vehículo nuevo
// - vehículo usado
//
// **customer segment**
//
// - cliente particular
// - empresa
// - autónomo
// - pyme
// - flota

// %%
pl.DataFrame(bodyEnts).filter(pl.col('type').neq(pl.lit('ev_model')))
// Out:
// <table><thead><tr><th>name</th><th>type</th></tr></thead><tbody><tr><td>coche eléctrico</td><td>electric_vehicle</td></tr><tr><td>vehículo eléctrico</td><td>electric_vehicle</td></tr><tr><td>coches eléctricos</td><td>electric_vehicle</td></tr><tr><td>vehículos electrificados</td><td>electric_vehicle</td></tr><tr><td>vehículo eléctrico de batería</td><td>electric_vehicle_type</td></tr><tr><td>bev</td><td>electric_vehicle_type</td></tr><tr><td>vehículo híbrido enchufable</td><td>electric_vehicle_type</td></tr><tr><td>phev</td><td>electric_vehicle_type</td></tr><tr><td>vehículo de pila de combustible de hidrógeno</td><td>electric_vehicle_type</td></tr><tr><td>fcev</td><td>electric_vehicle_type</td></tr><tr><td>furgoneta eléctrica</td><td>electric_vehicle_type</td></tr><tr><td>movilidad eléctrica</td><td>concept</td></tr><tr><td>movilidad sostenible</td><td>concept</td></tr><tr><td>emisiones de co2</td><td>concept</td></tr><tr><td>huella de carbono</td><td>concept</td></tr><tr><td>zona de bajas emisiones</td><td>policy_instrument</td></tr><tr><td>punto de carga</td><td>infrastructure</td></tr><tr><td>punto de recarga</td><td>infrastructure</td></tr><tr><td>infraestructura de recarga</td><td>infrastructure</td></tr><tr><td>enchufe para coches eléctricos</td><td>infrastructure</td></tr><tr><td>cargador</td><td>infrastructure</td></tr><tr><td>instalación de un punto de carga</td><td>subsidy_measure</td></tr><tr><td>plan moves iii</td><td>subsidy_program</td></tr><tr><td>ayudas estatales</td><td>subsidy_category</td></tr><tr><td>ayudas autonómicas</td><td>subsidy_category</td></tr><tr><td>ayuda adicional para achatarramiento</td><td>subsidy_measure</td></tr><tr><td>ayuda adicional para colectivos específicos</td><td>subsidy_measure</td></tr><tr><td>subvenciones para puntos de recarga de coches eléctricos</td><td>subsidy_measure</td></tr><tr><td>ayudas para coches eléctricos</td><td>subsidy_category</td></tr><tr><td>ayudas directas</td><td>subsidy_category</td></tr><tr><td>deducción fiscal</td><td>tax_incentive</td></tr><tr><td>deducciones fiscales</td><td>tax_incentive</td></tr><tr><td>deducción en la declaración de la renta</td><td>tax_incentive</td></tr><tr><td>deducción en el irpf</td><td>tax_incentive</td></tr><tr><td>deducción del 15%</td><td>tax_incentive</td></tr><tr><td>base de la deducción</td><td>tax_incentive_detail</td></tr><tr><td>límite máximo de la base de la deducción</td><td>tax_incentive_detail</td></tr><tr><td>amortización</td><td>tax_incentive_detail</td></tr><tr><td>iva deducible</td><td>tax_incentive_detail</td></tr><tr><td>exenciones en el pago del impuesto de matriculación</td><td>tax_incentive</td></tr><tr><td>declaración de la renta</td><td>tax_context</td></tr><tr><td>ejercicio fiscal</td><td>tax_context</td></tr><tr><td>agencia tributaria</td><td>government_body</td></tr><tr><td>instituto para la diversificación y ahorro de la energía</td><td>government_body</td></tr><tr><td>idae</td><td>government_body</td></tr><tr><td>base de vehículos del idae</td><td>regulatory_list</td></tr><tr><td>rd 266/2021</td><td>regulation</td></tr><tr><td>rdl 5/2023</td><td>regulation</td></tr><tr><td>ayuda plan moves iii</td><td>subsidy_measure</td></tr><tr><td>ayuda adicional del 10%</td><td>subsidy_measure</td></tr></tbody></table>

// %% [markdown]
// # Own content

// %%
...
// Out:
// Expression expected at file:///repl.tsx:1:1
//
//   ...
//   ~~~: Expression expected at file:///repl.tsx:1:1
//
//   ...
//   ~~~

// %% [markdown]
// # Create Content
//
// Create content automatically, or generate a brief for what content should be created

// %% [markdown]
// ## Auto-generate FAQ
