// %%
import { load } from "@std/dotenv";

import { z } from '@zod/zod';

import { readParquetRows } from "../src/utils.ts";
import { scorePromptRelevance, AnalysisContext } from "../src/api.ts";
import { searchOpenAI } from "../src/search.ts";

// %%
void await load({
  envPath: "../.env",
  export: true,
});

// %%
const filePath = '/Users/thomas/Downloads/Expanded Keywords_2025-11-05T12_58_01.parquet';
const keywords = await readParquetRows(filePath);

// %%
keywords[0]
// Out:
// {
//   ROWID: 1,
//   keyword: "social media analytics",
//   avgMonthlySearches: 2900,
//   competition: "LOW",
//   competitionIndex: 12,
//   averageCpc: 26.263324737548828,
//   lowTopOfPageBid: 5.002618789672852,
//   highTopOfPageBid: 25.136112213134766,
//   searchVolume: {
//     list: [
//       { element: 2400 },
//       { element: 2400 },
//       { element: 2900 },
//       { element: 3600 },
//       { element: 2400 },
//       { element: 2900 },
//       { element: 2900 },
//       { element: 2900 },
//       { element: 2400 },
//       { element: 1900 },
//       { element: 1600 },
//       { element: 5400 }
//     ]
//   },
//   searchVolumeDate: {
//     list: [
//       { element: 2024-10-01T00:00:00.000Z },
//       { element: 2024-11-01T00:00:00.000Z },
//       { element: 2024-12-01T00:00:00.000Z },
//       { element: 2025-01-01T00:00:00.000Z },
//       { element: 2025-02-01T00:00:00.000Z },
//       { element: 2025-03-01T00:00:00.000Z },
//       { element: 2025-04-01T00:00:00.000Z },
//       { element: 2025-05-01T00:00:00.000Z },
//       { element: 2025-06-01T00:00:00.000Z },
//       { element: 2025-07-01T00:00:00.000Z },
//       { element: 2025-08-01T00:00:00.000Z },
//       { element: 2025-09-01T00:00:00.000Z }
//     ]
//   },
//   searchVolumeGrowthYoy: 125,
//   searchVolumeGrowth3m: 184.2105255126953,
//   searchVolumeGrowth1m: 237.5,
//   searchVolumeTrend: 0.017804155126214027,
//   concepts: { list: null },
//   conceptGroups: { list: null },
//   ROWID_1: 1
// }

// %%
const context: AnalysisContext = {
    brand: "metricool",
    sector: "social media management",
    market: "US",
    brief: "I'm interested in keywords for SEO that correspond to transactional intents related to social media management tools like metricool.com, focusing on features like social media scheduling, social media analytics, and AI social content creation.",
};

let ks: Array<string> = keywords.map((k) => k.keyword);

// %%
ks.slice(-10, -1)
// Out:
// [
//   "small business loyalty program ideas",
//   "best brand loyalty programs",
//   "us bank referral bonus",
//   "video testimonial template",
//   "ambassador influencer program",
//   "ambassador program examples",
//   "refer a friend marriott bonvoy",
//   "southwest airlines refer a friend",
//   "athlete ambassador programs"
// ]

// %%
ks = [
    "social media scheduling tools",
    "data analytics",
    "us bank referral bonus",
    "video testimonial template",
    "ambassador influencer program",
]
// Out:
// [
//   "social media scheduling tools",
//   "data analytics",
//   "us bank referral bonus",
//   "video testimonial template",
//   "ambassador influencer program"
// ]

// %%
const relevanceScores = await scorePromptRelevance(ks, context);
// Out:
// Scoring prompt relevance...

// %%
await Deno.writeTextFile(
    "./keyword_relevance_scores.json",
    JSON.stringify(
        ks.map((keyword, index) => ({
            keyword,
            relevance_score: relevanceScores[index]
        })),
        null,
        2
    )
);

// %%
let sr = await searchOpenAI({
    prompt: "social media scheduling tools",
    model: "gpt-4.1",
    useSearch: true,
    countryISOCode: "US",
    contextSize: "low",
    searchTool: "web_search"
});

console.log(sr.answer);
for (const source of sr.sources) {
    console.log(`- ${source.title}: ${source.url}`);
}
// Out:
// Here’s an updated overview of the most noteworthy social media scheduling tools in 2025, based on recent comparisons and expert reviews:
//
// 1. **Buffer**
//    - Renowned for its simplicity and user-friendly interface.
//    - Free plan: connect up to 3 social accounts and queue up to 10 posts per account. Ideal for individuals or small teams ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Paid tiers start affordably around $5–$6 per month per channel, unlocking more scheduled posts and accounts ([schedchie.com](https://www.schedchie.com/blog/7-free--affordable-social-media-scheduling-tools-2025-edition?utm_source=openai)).
//
// 2. **Schedchie**
//    - A newer budget-focused platform offering unlimited posts and social accounts for a flat €7.99/month (~$8) ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Includes AI-powered content assistance (captions, hashtags), an integrated content calendar, and analytics—all at this price point ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//
// 3. **Later**
//    - Best for visually oriented platforms like Instagram, TikTok, and Pinterest.
//    - Features a drag-and-drop content calendar, grid preview, hashtag suggestions, and a link-in-bio tool ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Offers a free tier (1 profile per platform, up to 30 posts/month) ([schedchie.com](https://www.schedchie.com/blog/7-free--affordable-social-media-scheduling-tools-2025-edition?utm_source=openai)).
//
// 4. **Hootsuite**
//    - Veteran enterprise-grade tool with comprehensive platform support, content scheduling, bulk uploads, unified inbox, and extensive analytics ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - No free plan; pricing starts at ~$99/month for smaller teams ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//
// 5. **SocialBee**
//    - Excels at AI-powered scheduling and content recycling via category-based queues ([schedchie.com](https://www.schedchie.com/blog/7-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Suited for those managing evergreen and varied content streams. Category rotation helps maintain a balanced posting schedule.
//
// 6. **Sprout Social**
//    - Focused on in-depth analytics, CRM integration, and collaboration workflows—great for larger brands or agencies ([schedchie.com](https://www.schedchie.com/blog/7-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Higher price point but rich in features.
//
// 7. **Sendible**
//    - Offers a well-rounded scheduler with content calendar, social inbox, Canva integration, and analytics, at an accessible starting price (~$29/month) ([schedchie.com](https://www.schedchie.com/blog/7-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Ideal for solo professionals, agencies, or small businesses.
//
// 8. **Metricool**
//    - Combines scheduling with strong analytics, bulk posting, and even competitor analysis ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Free plan allows up to 50 posts/month; Starter plans are still cost-effective ([schedchie.com](https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai)).
//    - Notably, integrated into Adobe Express as of May 2025—allowing seamless design-to-schedule workflows within one platform ([lifewire.com](https://www.lifewire.com/metricool-adobe-express-integration-11745266?utm_source=openai)).
//
// 9. **Planable**
//    - Tailored for teams and agencies needing fast, visual collaboration and client approval workflows.
//    - Offers previews of posts, threaded comments, versioning, and approval layers ([buffer.com](https://buffer.com/resources/social-media-scheduling-tools/?utm_source=openai)).
//
// 10. **Predis.ai**
//     - AI-driven platform that supports auto-posting, content calendars, post generation, captions, and scheduling across major networks ([en.wikipedia.org](https://en.wikipedia.org/wiki/Predis.ai?utm_source=openai)).
//     - Highly rated for ease of use and effective automation.
//
// 11. **MeetEdgar**
//     - Focuses on automated recycling of evergreen content and generating post variations. Ideal for “set-and-forget” scheduling setups ([clinstitute.co.uk](https://clinstitute.co.uk/blog/digital-marketing/top-10-social-media-scheduling-tools-in-2025?utm_source=openai)).
//
// 12. **Additional tools to note**
//     - **Meta Business Suite**: native, free scheduling for Facebook and Instagram ([blog.hootsuite.com](https://blog.hootsuite.com/social-media-scheduling-tools/?utm_source=openai)).
//     - **Tailwind**: specialized in Pinterest and Instagram scheduling and interval planning ([blog.hootsuite.com](https://blog.hootsuite.com/social-media-scheduling-tools/?utm_source=openai)).
//     - **RSS Autopublisher**: auto-posts blog or feed content to social platforms via RSS ([blog.hootsuite.com](https://blog.hootsuite.com/social-media-scheduling-tools/?utm_source=openai)).
//
// ---
//
// Summary Table:
// • **Best for Beginners / Free Use**: Buffer, Meta Business Suite
// • **Best Budget with AI**: Schedchie, Predis.ai
// • **Visual Planning (Instagram focus)**: Later, Tailwind, MeetEdgar
// • **Analytics & Data-Driven**: Metricool, Sprout Social
// • **Team Collaboration / Approvals**: Planable, Sendible
// • **Evergreen / Content Recycling**: SocialBee, MeetEdgar
// • **Enterprise-Scale**: Hootsuite, Sprout Social
//
// Let me know if you'd like a deep dive into pricing tiers, integration capabilities, or tool recommendations tailored to your industry or team size!
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 7 Free & Affordable Social Media Scheduling Tools (2025 Edition) | Schedchie Blog: https://www.schedchie.com/blog/7-free--affordable-social-media-scheduling-tools-2025-edition?utm_source=openai
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 7 Free & Affordable Social Media Scheduling Tools (2025 Edition) | Schedchie Blog: https://www.schedchie.com/blog/7-free--affordable-social-media-scheduling-tools-2025-edition?utm_source=openai
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 7 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/7-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 7 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/7-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 7 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/7-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - 10 Best Social Media Scheduling Tools in 2025 | Schedchie Blog: https://www.schedchie.com/blog/10-best-social-media-scheduling-tools-in-2025?utm_source=openai
// - You Can Now Use Metricool Inside Adobe Express: https://www.lifewire.com/metricool-adobe-express-integration-11745266?utm_source=openai
// - The Best Social Media Scheduling Tools in 2025: https://buffer.com/resources/social-media-scheduling-tools/?utm_source=openai
// - Predis.ai: https://en.wikipedia.org/wiki/Predis.ai?utm_source=openai
// - Top 10 Social Media Scheduling Tools in 2025: https://clinstitute.co.uk/blog/digital-marketing/top-10-social-media-scheduling-tools-in-2025?utm_source=openai
// - 13 social media scheduling tools to save tons of time in 2025: https://blog.hootsuite.com/social-media-scheduling-tools/?utm_source=openai
// - 13 social media scheduling tools to save tons of time in 2025: https://blog.hootsuite.com/social-media-scheduling-tools/?utm_source=openai
// - 13 social media scheduling tools to save tons of time in 2025: https://blog.hootsuite.com/social-media-scheduling-tools/?utm_source=openai

// %%
const result = await searchOpenAI({
	prompt: 'What are the best restaurants in Madrid?',
	model: 'gpt-4.1-mini',
	countryISOCode: 'ES',
	useSearch: true,
	contextSize: 'medium',
	searchTool: 'web_search_preview'
});

result
// Out:
// {
//   answer: "Madrid boasts a vibrant culinary scene, offering a diverse array of dining experiences from traditional Spanish fare to avant-garde cuisine. Here are some of the city's top restaurants:\n" +
//     "\n" +
//     "**[Sobrino de Botín](http://www.botin.es/?utm_source=openai)**  \n" +
//     "**Closed · $$$ · 4.3 (15004 reviews)**  \n" +
//     "_C. de Cuchilleros, 17, Centro, 28005 Madrid, Spain_  \n" +
//     "Established in 1725, recognized by Guinness World Records as the world's oldest restaurant, famed for its roast suckling pig cooked in the original wood-fired oven.\n" +
//     "\n" +
//     "**[Coque](https://restaurantecoque.com/?utm_source=openai)**  \n" +
//     "**Closed · €100+ · 4.7 (1640 reviews)**  \n" +
//     "_C. del Marqués del Riscal, 11, Chamberí, 28010 Madrid, Spain_  \n" +
//     "A two-Michelin-starred restaurant in Chamberí, helmed by Chef Mario Sandoval, known for its innovative approach to traditional Spanish cuisine, especially its signature suckling pig.\n" +
//     "\n" +
//     "**[The Library Wine Boutique & Cuisine](https://thelibraryboutique.com/?utm_source=openai)**  \n" +
//     "**Closed · 4.1 (449 reviews)**  \n" +
//     "_C. de Serrano, 2, Salamanca, 28001 Madrid, Spain_  \n" +
//     "Located on Calle Serrano, this restaurant offers a unique dining experience with a wine bar, vinoteca boasting over 3,500 wines, and a private club, recently awarded the People's Choice Award for Best New Opening in 2024.\n" +
//     "\n" +
//     "**[Bascoat](https://www.bascoatmadrid.com/?utm_source=openai)**  \n" +
//     "**Closed · €100+ · 4.4 (197 reviews)**  \n" +
//     "_P.º de La Habana, 33, Chamartín, 28036 Madrid, Spain_  \n" +
//     "Situated on Paseo de la Habana, Bascoat specializes in a reinterpretation of Basque cuisine, offering a 12-course tasting menu for €150, and was recognized as the Best New Opening in 2023.\n" +
//     "\n" +
//     "**[Horcher](http://restaurantehorcher.com/?utm_source=openai)**  \n" +
//     "**Closed · €100+ · 4.6 (675 reviews)**  \n" +
//     "_C. de Alfonso XII, 6, Retiro, 28014 Madrid, Spain_  \n" +
//     "A historic restaurant located near Retiro Park, offering specialties like potato pancakes, Wiener schnitzel, and Baumkuchen, and is among the top 25 restaurants in Madrid as of 2025.\n" +
//     "\n" +
//     "These establishments represent the pinnacle of Madrid's dining scene, each offering a unique culinary experience that reflects the city's rich gastronomic heritage and innovative spirit. ",
//   sources: [
//     {
//       title: "Sobrino de Botín",
//       url: "http://www.botin.es/?utm_source=openai",
//       domain: "botin.es"
//     },
//     {
//       title: "Coque",
//       url: "https://restaurantecoque.com/?utm_source=openai",
//       domain: "restaurantecoque.com"
//     },
//     {
//       title: "The Library Wine Boutique & Cuisine",
//       url: "https://thelibraryboutique.com/?utm_source=openai",
//       domain: "thelibraryboutique.com"
//     },
//     {
//       title: "Bascoat",
//       url: "https://www.bascoatmadrid.com/?utm_source=openai",
//       domain: "bascoatmadrid.com"
//     },
//     {
//       title: "Horcher",
//       url: "http://restaurantehorcher.com/?utm_source=openai",
//       domain: "restaurantehorcher.com"
//     }
//   ]
// }
