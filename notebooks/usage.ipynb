// %% [markdown]
// # Generate prompts

// %%
import { PromptGenerator } from '../mod.ts';

const generator = new PromptGenerator(
    {
        minPrompts: 5,
        maxPrompts: 10,
        language: 'English',
        topics: [
            { topic: 'AI visibility', subtopics: ['ranking factors', 'prompt coverage'] }
        ],
        personas: [
            { name: 'SEO lead', description: 'Owns search visibility strategy at a SaaS company' },
        ],
        intents: ['informational', 'comparison', 'transactional']
    },
    { model: 'gpt-4.1' }
);

const result = await generator.invoke('Generate prompts for a B2B AI visibility tool.');
console.log(result.parsed);
// Out:
// [
//   {
//     prompt: "What are the main factors that influence my company's visibility in AI-powered search engines?",
//     intent: "informational"
//   },
//   {
//     prompt: "How does your AI visibility tool measure prompt coverage for enterprise websites?",
//     intent: "informational"
//   },
//   {
//     prompt: "Can you compare your AI visibility tool with other solutions for tracking B2B ranking factors?",
//     intent: "comparison"
//   },
//   {
//     prompt: "What improvements can I make to my SaaS company's content to rank higher in AI search results?",
//     intent: "informational"
//   },
//   {
//     prompt: "How can I purchase a subscription to your AI visibility tool for my marketing team?",
//     intent: "transactional"
//   },
//   {
//     prompt: "Does your tool provide insights into specific prompt gaps affecting our visibility in AI search?",
//     intent: "informational"
//   },
//   {
// ...
